# %%
import json, mimetypes, time, sys, asyncio
from pathlib import Path
from concurrent.futures import ThreadPoolExecutor, as_completed
import requests

# Optional Playwright
try:
    from playwright.sync_api import sync_playwright
    PLAYWRIGHT_AVAILABLE = True
except ImportError:
    PLAYWRIGHT_AVAILABLE = False

# Use the Proactor loop on Windows (needed for Playwright subprocess)
if sys.platform.startswith("win"):
    asyncio.set_event_loop_policy(asyncio.WindowsProactorEventLoopPolicy())

# ---------- CONFIG: folder with deduplicated.json ----------
BASE_DIR = Path(r"C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer")
dedup_file = BASE_DIR / "deduplicated.json"
files_dir = BASE_DIR / "files"
pages_dir = BASE_DIR / "web pages"
files_dir.mkdir(exist_ok=True)
pages_dir.mkdir(exist_ok=True)

UA = "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36"
TIMEOUT = 60
MAX_HTTP_WORKERS = 12

manifest = []
pending_render = []  # queued for main-thread Playwright

def clean_url(url: str) -> str:
    url = url.strip().strip("*_")
    if not url.startswith(("http://", "https://")):
        url = "https://" + url
    return url

def classify_via_headers(url: str):
    try:
        r = requests.head(url, allow_redirects=True, timeout=TIMEOUT, headers={"User-Agent": UA})
        return r.headers.get("Content-Type", "").lower(), r.headers.get("Content-Disposition", "")
    except Exception:
        return "", ""

def guess_name(url: str, disp: str, ctype: str):
    if "filename=" in disp:
        name = disp.split("filename=")[-1].strip("\"'; ")
        if name:
            return name
    path_part = url.split("?")[0].rstrip("/").split("/")[-1]
    if path_part:
        return path_part
    ext = mimetypes.guess_extension(ctype.split(";")[0].strip()) if ctype else ".bin"
    return f"download{ext or '.bin'}"

def save_file(url: str, ctype: str, disp: str):
    name = guess_name(url, disp, ctype or "")
    target = files_dir / name
    with requests.get(url, stream=True, allow_redirects=True, timeout=TIMEOUT, headers={"User-Agent": UA}) as r:
        r.raise_for_status()
        with open(target, "wb") as f:
            for chunk in r.iter_content(chunk_size=8192):
                if chunk:
                    f.write(chunk)
    return str(target)

def save_html_raw(url: str):
    r = requests.get(url, allow_redirects=True, timeout=TIMEOUT, headers={"User-Agent": UA})
    r.raise_for_status()
    name = guess_name(url, "", "text/html")
    if not name.lower().endswith(".html"):
        name += ".html"
    target = pages_dir / name
    target.write_text(r.text, encoding=r.encoding or "utf-8", errors="ignore")
    return str(target)

def save_html_rendered(url: str):
    if not PLAYWRIGHT_AVAILABLE:
        return None
    with sync_playwright() as p:
        browser = p.chromium.launch(headless=True)
        page = browser.new_page()
        page.goto(url, wait_until="networkidle", timeout=TIMEOUT * 1000)
        page.evaluate("window.scrollTo(0, document.body.scrollHeight)")
        page.wait_for_timeout(2000)
        html = page.content()
        name = guess_name(url, "", "text/html")
        if not name.lower().endswith(".html"):
            name += ".rendered.html"
        target = pages_dir / name
        target.write_text(html, encoding="utf-8", errors="ignore")
        browser.close()
        return str(target)

def process_url_http(url: str):
    record = {"url": url, "status": "unknown", "saved": None, "type": None, "error": None}
    try:
        ctype, disp = classify_via_headers(url)
        is_file = any(s in ctype for s in ["application/", "image/", "audio/", "video/"]) or "filename=" in disp
        if is_file:
            record["saved"] = save_file(url, ctype, disp)
            record["type"] = "file"
            record["status"] = "ok"
            return record
        # Try raw HTML
        record["saved"] = save_html_raw(url)
        record["type"] = "html_raw"
        record["status"] = "ok"
        return record
    except Exception as e:
        record["error"] = repr(e)
        # Queue for render fallback (main thread) if available
        if PLAYWRIGHT_AVAILABLE:
            record["status"] = "pending_render"
            pending_render.append(record)
        else:
            record["status"] = "failed"
        return record

# Load URLs
data = json.loads(dedup_file.read_text(encoding="utf-8"))
urls = []
for key, entry in data.items():
    if key == "_meta":
        continue
    raw = entry.get("original form") or entry.get("bare minimum form") or ""
    if raw:
        urls.append(clean_url(raw))

start = time.time()

# Phase 1: HTTP in parallel
with ThreadPoolExecutor(max_workers=MAX_HTTP_WORKERS) as pool:
    futures = {pool.submit(process_url_http, u): u for u in urls}
    for fut in as_completed(futures):
        rec = fut.result()
        manifest.append(rec)
        print(f"{rec['status']:12} {rec['type'] or '-':12} {rec['url']} -> {rec['saved']}")

# Phase 2: Render pending URLs in main thread (sequential)
if PLAYWRIGHT_AVAILABLE and pending_render:
    print(f"\nRendering {len(pending_render)} URLs via Playwright...")
    for rec in pending_render:
        try:
            saved = save_html_rendered(rec["url"])
            rec["saved"] = saved
            rec["type"] = "html_rendered"
            rec["status"] = "ok"
            rec["error"] = None
            print(f"ok           html_rendered  {rec['url']} -> {saved}")
        except Exception as e:
            rec["status"] = "failed"
            rec["error"] = repr(e)
            print(f"failed       -              {rec['url']} -> {rec['error']}")

manifest_path = BASE_DIR / "fetch_manifest.json"
manifest_path.write_text(json.dumps(manifest, indent=2), encoding="utf-8")
print(f"\nDone in {time.time() - start:0.2f}s. Manifest: {manifest_path}")
# Out:
# ok           html_raw     https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K123174 -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\web pages\pmn.cfm.html
# ok           html_raw     https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K083018 -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\web pages\pmn.cfm.html
# ok           file         https://www.gehealthcare.com/-/jssmedia/gehc/us/files/products/truepacpage/solution-brief-edison-true-radiology-iw.pdf?rev=-1 -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\files\solution-brief-edison-true-radiology-iw.pdf
# ok           file         https://www.gehealthcare.com/-/jssmedia/documents/us-global/products/interoperability/dicom/radiology-pacs-ris/gehc-dicom-conformance_enterprisearchive8_doc2512664_rev12.pdf?hash=101C6005B08396A390A024CB0C4337E6&rev=-1 -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\files\GEHC-DICOM-Conformance_EnterpriseArchive8_DOC2512664_Rev12.pdf
# ok           file         https://www.accessdata.fda.gov/cdrh_docs/pdf8/K083018.pdf -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\files\K083018.pdf
# ok           html_raw     https://www.gehealthcare.com/products/software/true-pacs -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\web pages\true-pacs.html
# ok           html_raw     https://www.gehealthcare.com/products/software/enterprise-imaging/centricity-universal-viewer -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\web pages\centricity-universal-viewer.html
# ok           file         https://www.accessdata.fda.gov/cdrh_docs/pdf12/K123174.pdf -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\files\K123174.pdf
# failed       -            https://www.gehealthcare.com/-/jssmedia/documents/us-global/products/interoperability/dicom/radiology-pacs-ris/gehc-dicom-conformance_centricitypacs_70_doc2327903_rev1.pdf?hash=5C7E2DADCD5FAD24B375B667DE536603&rev=-1&srsltid=AfmBOoqWysjA2OAQ-z1Vf6XpXKl_XqNQ6PpSkAbMJv-PK6yrVwKQH1B- -> None
# ok           file         https://www.gehealthcare.com/-/jssmedia/documents/us-global/products/interoperability/dicom/radiology-pacs-ris/doc1663578-universal-viewer-zfp-dicom-conformance-statement.pdf?hash=8A18B56552A4617C7D429AD1745AC58F&rev=-1&srsltid=AfmBOor87R3SzaHxUNYJp34kknklPdoL5MW2CmM6suMHv9YBYPdmmfIe -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\files\DOC1663578 Universal Viewer ZFP Dicom Conformance Statement.pdf
# ok           file         https://www.gehealthcare.com/-/jssmedia/gehc/us/files/products/interoperability/dicom/radiology-pacs-and-ris-conformance-statements/universal-viewer-70-dicom-conformance-statement--1.pdf?hash=79CDCDA863BF1C96430D6FB11D67F91E&rev=-1&srsltid=AfmBOoqCFftM1cFr5qs2mohECr1MdrXyneVky780Va2AhhfnQKhlJqkU -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\files\Universal Viewer 70 DICOM Conformance Statement -1.pdf
# ok           file         https://www.accessdata.fda.gov/cdrh_docs/pdf18/K182419.pdf -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\files\K182419.pdf
# ok           html_raw     https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K182419 -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\web pages\pmn.cfm.html
# ok           file         https://www.accessdata.fda.gov/cdrh_docs/pdf13/K131977.pdf -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\files\K131977.pdf
# ok           html_raw     https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K131977 -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\web pages\pmn.cfm.html
# ok           html_raw     https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfres/res.cfm?id=79449 -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\web pages\res.cfm.html
# ok           file         https://www.gehealthcare.com/-/jssmedia/documents/us-global/products/interoperability/dicom/radiology-pacs-ris/gehc-dicom-conformance_centricitypacs-iw_3739_doc1148833_rev3.pdf?hash=73B6F6AA2EA0A4405351C252569864CA&rev=-1&srsltid=AfmBOopUDY3GkpmsynuT2BNFj_kTcmmAUXLGu0bG0897EZxgtEdr5JrR -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\files\GEHC-DICOM-Conformance_CentricityPACS-IW_3739_DOC1148833_Rev3.pdf
# ok           file         https://www.accessdata.fda.gov/cdrh_docs/pdf8/K082318.pdf -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\files\K082318.pdf
# ok           html_raw     https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfres/res.cfm?id=209804 -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\web pages\res.cfm.html
# ok           html_raw     https://www.gehealthcare.com/products/software/edison-true-pacs -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\web pages\edison-true-pacs.html
# ok           file         https://www.gehealthcare.com/-/jssmedia/gehc/us/images/products/healthcare-it/edison-true-pacs/redesign/solution-brief-edison-true-pacs-radiology.pdf?rev=-1 -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\files\solution-brief-edison-true-pacs-radiology.pdf
# ok           html_raw     https://www.gehealthcare.com/products/interoperability/dicom/radiology-pacs-and-ris-conformance-statements -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\web pages\radiology-pacs-and-ris-conformance-statements.html
# ok           html_raw     https://www.gehealthcare.com/products/interoperability/ihe/radiology-pacs-workstations-mammo-ris-ihe-integration-statements -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\web pages\radiology-pacs-workstations-mammo-ris-ihe-integration-statements.html
# ok           html_raw     https://www.loadbalancer.org/applications/ge-healthcare-true-pacs-tp/ -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\web pages\ge-healthcare-true-pacs-tp.html
# ok           html_raw     https://www.gehealthcare.com/products/interoperability/hl7 -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\web pages\hl7.html
# ok           html_raw     https://aws.amazon.com/marketplace/pp/prodview-gcr5g5kkavtze -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\web pages\prodview-gcr5g5kkavtze.html
# ok           file         https://www.gehealthcare.com/-/jssmedia/widen/2018/01/25/0204/gehealthcarecom/migrated/2018/02/19/0841/ty-dicom-radiology-pacs-ris-gehc-dicom-conformance_centricitypacs-v4-0_doc1145900_rev3_pdf.pdf?rev=-1&hash=7BAEAEDF6D743A82EC1EDDB0A7C96F2B -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\files\ty-dicom-radiology-pacs-ris-gehc-dicom-conformance_centricitypacs-v4-0_doc1145900_rev3_pdf.pdf
# ok           file         http://www.medequal.com/site/wp-content/uploads/2024/05/GE-product-datasheet-universal-viewer-zfp-sp11-.pdf -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\files\GE-product-datasheet-universal-viewer-zfp-sp11-.pdf
# ok           file         https://www.gehealthcare.com/-/jssmedia/documents/us-global/products/interoperability/dicom/radiology-pacs-ris/gehc-dicom-conformance_enterprisearchive8_doc2512664_rev12.pdf?rev=-1&hash=101C6005B08396A390A024CB0C4337E6 -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\files\GEHC-DICOM-Conformance_EnterpriseArchive8_DOC2512664_Rev12.pdf
# ok           html_raw     https://www.scribd.com/document/100804659/Guide-to-Centricity-Pacs-iw-hanging-Protocols-ver-20110912-01 -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\web pages\Guide-to-Centricity-Pacs-iw-hanging-Protocols-ver-20110912-01.html
# failed       -            https://summaries.Let -> None
# failed       -            https://information.Based -> None
# ok           html_raw     https://gehealthcare.com -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\web pages\gehealthcare.com.html
# failed       -            https://www3.gehealthcare.com/~/media/documents/us-global/products/interoperability/dicom/radiology-pacs-ris/gehc-dicom-conformance_centricitypacs-v4-0-sp5_2064225-001_rev4.pdf -> None
# ok           html_raw     https://Loadbalancer.org -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\web pages\Loadbalancer.org.html
# ok           file         https://geiselmed.dartmouth.edu/radiology/wp-content/uploads/sites/47/2019/03/Hanging-Protocol-Guide.pdf -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\files\Hanging-Protocol-Guide.pdf
# failed       -            https://empoweringeducation.gehealthcare.com/tims/curriculums -> None
# ok           html_raw     https://www.youtube.com/watch?v=ra2aWnfHgm0 -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\web pages\watch.html
# ok           file         https://www.gehealthcare.com/-/media/documents/us-global/support/site-planning/site-readiness/gehc-sp_quickstart_guide_pacs.pdf?la=en-us -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\files\GEHC-SP_QUICKSTART_GUIDE_PACS.pdf
# ok           file         https://pdfs.loadbalancer.org/GE_True_PACS_Deployment_Guide.pdf -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\files\GE_True_PACS_Deployment_Guide.pdf
# ok           file         https://www.gehealthcare.com/-/jssmedia/gehc/us/files/services/cybersecurity/2001145-cybersecurity-white-paperv5jan102022finalapproved.pdf?rev=-1 -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\files\2001145-Cybersecurity-White-Paperv5Jan102022finalapproved.pdf
# ok           file         https://www.gehealthcare.com/-/jssmedia/global/products/files/healthcare-digital/centricity-universal-viewer/universal-viewer-zfp-power-of-one-brochure-jb52502xx.pdf -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\files\Universal-Viewer-ZFP-Power-of-One-Brochure-JB52502XX.pdf
# ok           html_raw     https://www.gehealthcare.com/about/contact-us -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\web pages\contact-us.html
# ok           file         https://www.gehealthcare.com/-/media/documents/us-global/support/site-planning/site-readiness/gehc-sp_multi-modality_implementation_guide.pdf?la=en-us -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\files\GEHC-SP_MULTI-MODALITY_IMPLEMENTATION_GUIDE.pdf
# ok           html_raw     https://www.gehealthcare.com/products/software/pacs-and-ai-orchestration -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\web pages\pacs-and-ai-orchestration.html
# ok           file         https://www.gehealthcare.com/-/media/widen/2018/01/25/0204/gehealthcarecom/migrated/2018/02/19/0841/gy-pacs-ris-gehc-dicom-conformance_universal-viewer-web-client-5-0-sp5_doc1198183_rev4_pdf.pdf -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\files\gy-pacs-ris-gehc-dicom-conformance_universal-viewer-web-client-5-0-sp5_doc1198183_rev4_pdf.pdf
# ok           file         https://www.gehealthcare.com/-/jssmedia/documents/us-global/products/interoperability/dicom/radiology-pacs-ris/centricity-universal-viewer-zero-footprint-direction--doc2089507.pdf -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\files\Centricity Universal Viewer Zero Footprint Direction  DOC2089507.pdf
# ok           file         https://www.gehealthcare.com/-/media/09f7b5678aaa42d4ba9f3df59ea0fb07.pdf -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\files\healthcare-it-Universal-Viewer-Power-of-One-Brochure-JB52859XX2.pdf
# failed       -            https://www.businesswire.com/news/home/20241009852041/en/GE-HealthCare-Accelerates-Artificial-Intelligence-Adoption-With-New-Offering-to-Advance-Enterprise-Imaging -> None
# ok           file         https://www.gehealthcare.com/-/jssmedia/widen/2018/01/25/0204/gehealthcarecom/migrated/2018/02/19/0841/dicom-radiology-pacs-ris-gehc-dicom-conformance_centricitypacs-v3-0_2017753-209_rev0-9_pdf.pdf -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\files\dicom-radiology-pacs-ris-gehc-dicom-conformance_centricitypacs-v3-0_2017753-209_rev0-9_pdf.pdf
# ok           file         https://www.gehealthcare.com/-/jssmedia/widen/2018/01/25/0204/gehealthcarecom/migrated/2018/02/19/0841/dicom-radiology-pacs-ris-gehc-dicom-conformance_centricitypacs-iw-v5-0_doc1193612_rev3_pdf.pdf -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\files\dicom-radiology-pacs-ris-gehc-dicom-conformance_centricitypacs-iw-v5-0_doc1193612_rev3_pdf.pdf
# failed       -            https://www.gehealthcare.com/products/software/enterprise-imaging/centricity-universal-viewer-zero-footprint -> None
# failed       -            https://www.auntminnie.com/imaging-informatics/enterprise-imaging/pacs-vna/news/15746673/ge-healthcare-ge-healthcare-announces-new-integrations-with-pacs -> None
# failed       -            https://www.childrensmn.org/for-health-professionals/resources/emr-updates/2025/02/13/upcoming-pacs-upgrade-transition-to-ge-truepacs/ -> None
# ok           html_raw     https://medicalalley.org/ge-launches-ai-based-edison-true-pacs-system/ -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\web pages\ge-launches-ai-based-edison-true-pacs-system.html
# ok           html_raw     https://www.loadbalancer.org/applications/ge-healthcare-centricity-pacs/ -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\web pages\ge-healthcare-centricity-pacs.html
# ok           file         https://www.gehealthcare.com/-/jssmedia/documents/us-global/products/interoperability/dicom/radiology-pacs-ris/gehc-dicom-conformance_centricitypacs-iw_3739_doc1148833_rev3.pdf -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\files\GEHC-DICOM-Conformance_CentricityPACS-IW_3739_DOC1148833_Rev3.pdf
# ok           html_raw     https://appliedradiology.com/articles/himss-2021-ge-introduces-edison-true-pacs -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\web pages\himss-2021-ge-introduces-edison-true-pacs.html
# ok           html_raw     https://landing1.gehealthcare.com/centricity-universal-viewer-zero-footprint-white-paper.html -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\web pages\centricity-universal-viewer-zero-footprint-white-paper.html
# ok           file         https://www.gehealthcare.com/-/jssmedia/documents/us-global/products/interoperability/dicom/radiology-pacs-ris/doc1663578-universal-viewer-zfp-dicom-conformance-statement.pdf?rev=-1 -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\files\DOC1663578 Universal Viewer ZFP Dicom Conformance Statement.pdf
# ok           file         https://www.gehealthcare.com/-/media/Documents/US-Global/Products/Healthcare-it/Centricity-Clinical-Archive/case-study-large-enterprise-vna-edison-datalogue-JB73537XX -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\files\case-study-large-enterprise-vna-edison-datalogue-JB73537XX.pdf
# failed       -            https://www.gehealthcare.com/products/software/true-pacs] -> None
# failed       -            https://device.report/m/49a6a907241466d3d6782f473dbafc92c38bcf73a21ef24101929ccbecd591a1.pdf -> None
# ok           file         https://www.gehealthcare.com/-/jssmedia/gehc/us/files/products/interoperability/dicom/radiology-pacs-and-ris-conformance-statements/enterprise_archive_8_dicom_conformance_statement.pdf?rev=-1 -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\files\Enterprise_Archive_8_DICOM_Conformance_Statement.pdf
# ok           file         https://www.accessdata.fda.gov/cdrh_docs/pdf21/K211312.pdf -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\files\K211312.pdf
# ok           file         https://www.gehealthcare.com/-/jssmedia/eb9de4f7d5b143ada8f345091e788f02.pdf?la=en-us -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\files\GEHC-Native-Breast-Imaging-Sell-Sheet-JB55958XX-1.pdf
# failed       -            https://www.gehealthcare.com/-/jssmedia/documents/us-global/products/interoperability/dicom/radiology-pacs-ris/gehc-dicom-conformance-statement-centricity-pacs-7.0-doc2327903.pdf -> None
# failed       -            https://device.report/m/b30652d6a2495b4fe3cfa7b694b687672187badae0016c72138992731e0e556d.pdf -> None
# failed       -            https://www.gehealthcare.com/-/media/documents/us-global/products/interoperability/dicom/radiology-pacs-ris/universal-viewer-v80-dicom-conformance-statement-doc2546408.pdf -> None
# ok           file         http://www.medequal.com/site/wp-content/uploads/2024/05/GE-product-data-sheet-universaI-viewer-web-V8.0-1-.pdf -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\files\GE-product-data-sheet-universaI-viewer-web-V8.0-1-.pdf
# failed       -            https://www.gehealthcare.com/-/jssmedia/documents/us-global/products/interoperability/ihe/radiology-pacs-workstations-mammography-workstations/universal-viewer-zfp-v6.0-sp2-ihe-integration-statement-doc2089507.pdf -> None
# ok           file         http://www.medequal.com/site/wp-content/uploads/2024/05/GE-Enterprise-Archive-V8-Product-Data-Sheet-Released-.pdf -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\files\GE-Enterprise-Archive-V8-Product-Data-Sheet-Released-.pdf
# ok           file         https://events.dev.gehealthcare.com/wp-content/uploads/2024/01/brochure-enterprise-imaging.pdf -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\files\brochure-enterprise-imaging.pdf
# ok           html_raw     https://www.youtube.com/watch?v=ZoHim0lPxTM -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\web pages\watch.html
# ok           file         https://nlchi.nl.ca/images/PDFs/March_2015_UV50_ZFP_OP.pdf -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\files\March_2015_UV50_ZFP_OP.pdf
# failed       -            https://www.gehealthcare.com/-/jssmedia/gehc/us/images/products/healthcare-it/edison-true-pacs/redesign/solution-brief-true-pacs-radiology.pdf -> None
# failed       -            https://www.itnonline.com/content/ge-healthcare-delivers-advanced-speech-understanding-pacs -> None
# ok           file         https://www.aha.org/system/files/media/file/2020/02/GEHC-Whitepaper_AutomatingRadiologyWorkflows.pdf -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\files\GEHC-Whitepaper_AutomatingRadiologyWorkflows.pdf
# ok           file         https://medhold.co.za/wp-content/uploads/2021/07/UNIVERSAL_VIEWER_DATA_SHEET.pdf -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\files\UNIVERSAL_VIEWER_DATA_SHEET.pdf
# ok           html_raw     https://www.gehealthcare.com/products/software/enterprise-imaging/centricity-clinical-archive -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\web pages\centricity-clinical-archive.html
# ok           file         https://aaita.com/media/PACS-Integration.pdf -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\files\PACS-Integration.pdf
# failed       -            https://www.gehealthcare.com/-/jssmedia/documents/us-global/products/interoperability/hl7/gehc-hl7-conformance-enterprisearchive-v8.0-doc2512673.pdf -> None
# ok           html_raw     https://www.digitalhealth.net/2022/07/royal-orthopaedic-hospital-to-deploy-new-cloud-based-pacs/ -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\web pages\royal-orthopaedic-hospital-to-deploy-new-cloud-based-pacs.html
# ok           html_raw     https://www.gehealthcare.com/about/newsroom/press-releases/ge-healthcare-amazon-web-services-bring-partnership-to-europe-with-first-cloud-deployment -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\web pages\ge-healthcare-amazon-web-services-bring-partnership-to-europe-with-first-cloud-deployment.html
# ok           html_raw     https://aws.amazon.com/solutions/case-studies/ge-healthcare/ -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\web pages\ge-healthcare.html
# ok           html_raw     https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K211312 -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\web pages\pmn.cfm.html
# ok           html_raw     https://www.gehealthcare.com/about/newsroom/press-releases/ge-healthcare-tops-list-for-third-year-in-a-row-with-highest-number-of-ai-enabled-medical-device-authorizations -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\web pages\ge-healthcare-tops-list-for-third-year-in-a-row-with-highest-number-of-ai-enabled-medical-device-authorizations.html
# ok           html_raw     https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K110875 -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\web pages\pmn.cfm.html
# failed       -            https://ge.com/ihe. -> None
# ok           html_raw     https://www.youtube.com/watch?v=tKiRQ4E9LxM -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\web pages\watch.html
# failed       -            https://www.gehealthcare.com/-/jssmedia/global/products/files/healthcare-it/centricity-universal-viewer/improving-breast-imaging-workflow-efficiencies-data-sheet.pdf -> None
# ok           html_raw     https://www.itnonline.com/content/ge-healthcare-tops-fda-list-ai-authorizations -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\web pages\ge-healthcare-tops-fda-list-ai-authorizations.html
# failed       -            https://gehealthcare.com/DICOM. -> None
# ok           html_raw     https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=k082318 -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\web pages\pmn.cfm.html
# ok           file         https://www.gehealthcare.de/-/jssmedia/gehc/us/images/products/healthcare-it/edison-true-pacs/redesign/solution-brief-true-pacs-radiology-2.pdf?rev=-1 -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\files\solution-brief-true-pacs-radiology 2.pdf
# ok           file         https://www.accessdata.fda.gov/cdrh_docs/pdf22/K223491.pdf -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\files\K223491.pdf
# ok           html_raw     https://www.healthcareitnews.com/news/fda-clears-ge-healthcares-ai-platform-x-ray-scans -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\web pages\fda-clears-ge-healthcares-ai-platform-x-ray-scans.html
# ok           html_raw     https://www.gehealthcare.com/about/newsroom/press-releases/ge-healthcare-accelerates-artificial-intelligence-adoption-with-new-offering-to-advance-enterprise-imaging -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\web pages\ge-healthcare-accelerates-artificial-intelligence-adoption-with-new-offering-to-advance-enterprise-imaging.html
# ok           file         https://www.accessdata.fda.gov/cdrh_docs/pdf23/K233698.pdf -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\files\K233698.pdf
# ok           html_raw     https://www.gehealthcare.com/products/healthcare-it/pacs-and-ai-orchestration -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\web pages\pacs-and-ai-orchestration.html
# ok           html_raw     https://www.gehealthcare.com/about/newsroom/press-releases/ge-healthcare-receives-fda-clearance-for-first-x-ray-ai-to-help-assess-endotracheal -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\web pages\ge-healthcare-receives-fda-clearance-for-first-x-ray-ai-to-help-assess-endotracheal.html
# ok           html_raw     https://healthairegister.com/news/updates-to-health-ai-register-october-2024 -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\web pages\updates-to-health-ai-register-october-2024.html
# ok           html_raw     https://www.gehealthcare.com/about/newsroom/press-releases/ge-healthcare-announces-fda-510k-clearance-for-revolution-vibe-ct-system-first-global-install-in-france -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\web pages\ge-healthcare-announces-fda-510k-clearance-for-revolution-vibe-ct-system-first-global-install-in-france.html
# ok           html_raw     https://www.massdevice.com/fda-clears-ge-healthcare-x-ray-algorithms/ -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\web pages\fda-clears-ge-healthcare-x-ray-algorithms.html
# ok           file         https://www.gehealthcare.com/-/media/widen/2018/01/25/0204/gehealthcarecom/migrated/2018/02/19/0841/gy-pacs-ris-gehc-dicom-conformance_universal-viewer-web-client-5-0-sp5_doc1198183_rev4_pdf.pdf?rev=-1&hash=EC1B0A8978A180E52BDE94A0D50466DC -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\files\gy-pacs-ris-gehc-dicom-conformance_universal-viewer-web-client-5-0-sp5_doc1198183_rev4_pdf.pdf
# ok           file         https://www.agfa.com/he/global/en/internet/he/library/libraryopen?ID=54472549 -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\files\001537_IMPAX_6.7.x_DICOM_Conformance_Statement.pdf
# ok           html_raw     https://www.gehealthcare.com/products/interoperability/dicom/cardiovascular-info-systems-dicom-conformance-statements -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\web pages\cardiovascular-info-systems-dicom-conformance-statements.html
# ok           file         https://www.gehealthcare.com/-/jssmedia/gehc/us/files/products/interoperability/dicom/radiology-pacs-and-ris-conformance-statements/enterprise_archive_8_dicom_conformance_statement.pdf?rev=-1&hash=31B5EFEBA27B4B2F022DD35E75961D0E -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\files\Enterprise_Archive_8_DICOM_Conformance_Statement.pdf
# ok           file         https://www.gehealthcare.com/-/jssmedia/documents/us-global/products/interoperability/dicom/radiology-pacs-ris/gehc-dicom-conformance_centricity-pacs-7-0_doc2327903_rev1.pdf?rev=-1&hash=59A7D1365FF79D9F71F9DE003DC49D6F -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\files\GEHC-DICOM-Conformance_Centricity-PACS-7-0_DOC2327903_Rev1.pdf
# ok           file         https://www.gehealthcare.com/-/media/documents/us-global/products/interoperability/dicom/radiology-pacs-ris/universal-viewer-v80-direction--doc2546408-rev-2.pdf?rev=-1&hash=F3626054197B4F3DB4A5174F59C7CC8F -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\files\Universal Viewer v80 Direction  DOC2546408 Rev 2.pdf
# failed       -            https://manuals.plus/m/b30652d6a2495b4fe3cfa7b694b687672187badae0016c72138992731e0e556d -> None
# ok           html_raw     https://www.scribd.com/document/893724986/Centricity-PACS -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\web pages\Centricity-PACS.html
# ok           html_raw     https://www.gehealthcare.co.uk/products/healthcare-it/pacs-and-ai-orchestration -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\web pages\pacs-and-ai-orchestration.html
# ok           file         https://ansm.sante.fr/uploads/2023/04/27/20230427-mes-pacscentricity-gehealthcare.pdf -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\files\20230427-mes-pacscentricity-gehealthcare.pdf
# ok           html_raw     https://www.gehealthcare.co.uk/products/healthcare-it/true-pacs -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\web pages\true-pacs.html
# ok           file         https://sectraprodstorage01.blob.core.windows.net/medical-uploads/2017/09/pacs-dicom-conformance-statement-15.2.pdf -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\files\pacs-dicom-conformance-statement-15.2.pdf
# ok           file         https://www.ulrichmedical.com/02-radiology/02-02-products/02-02-10-rispacs-interface/contrast-media-injector-ris-pacs-interface-sw-6-0-x-dicom-conformance-statement-xd10850-en.pdf -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\files\contrast-media-injector-ris-pacs-interface-sw-6-0-x-dicom-conformance-statement-xd10850-en.pdf
# failed       -            https://www.xr.co.za/UV%20Access%20UserManual.pdf -> None
# ok           html_raw     https://www.gehealthcare.com/support/manuals -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\web pages\manuals.html
# ok           file         https://medical.sectra.com/wp-content/uploads/sites/3/2021/04/conformance-statement-23-1.pdf -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\files\conformance-statement-23-1.pdf
# ok           file         https://www.childrensmn.org/departments/training/other/ge-etp-workflow-manager-universal-viewer-overview.pdf -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\files\ge-etp-workflow-manager-universal-viewer-overview.pdf
# ok           html_raw     https://www.scribd.com/document/748318412/solution-brief-edison-true-pacs-radiology -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\web pages\solution-brief-edison-true-pacs-radiology.html
# failed       -            https://device.report/m/49edb3e16bec6ed7ad8fd29d63426be7b776dbb47a2bc50b732b9b0ccf92ad4e.pdf -> None
# ok           html_raw     https://www.scribd.com/document/814389601/GE-PACS-Service-Manual -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\web pages\GE-PACS-Service-Manual.html
# ok           file         https://www.documents.philips.com/doclib/enc/fetch/2000/4504/577242/577256/588723/5144873/5144488/5144498/DICOM_Conformance_Statement_IntelliSpace_Cardiovascular_3.2.pdf -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\files\DICOM_Conformance_Statement_IntelliSpace_Cardiovascular_3.2.pdf
# ok           file         https://www.anogov.com/ss-ipocoimbra/faces/app/downloadDiretoDocumento;jsessionid=bc6930fa8d727e4d619580aff240cff4238dddf546823e9bf6262d5871ad4add.e34Ta30Oc3aKai0Oa3uRe0?papId=5851&docId=55660&fichId=70961&lang=en -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\files\downloadDiretoDocumento;jsessionid=bc6930fa8d727e4d619580aff240cff4238dddf546823e9bf6262d5871ad4add.e34Ta30Oc3aKai0Oa3uRe0
# ok           html_raw     https://www.itnonline.com/content/ge-healthcare-unveil-advanced-3d-mammography-image-reconstruction-technology -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\web pages\ge-healthcare-unveil-advanced-3d-mammography-image-reconstruction-technology.html
# ok           html_raw     https://www.itnonline.com/content/ge%E2%80%99s-pacs-suite-ups-automation-levels -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\web pages\ge%E2%80%99s-pacs-suite-ups-automation-levels.html
# ok           html_raw     https://www.bfarm.de/SharedDocs/Kundeninfos/EN/09/2020/17563-19_kundeninfo_en.pdf?__blob=publicationFile&v=1 -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\web pages\17563-19_kundeninfo_en.pdf.html
# ok           file         https://www.childrensmn.org/departments/training/other/ge-pacs-universal-viewer-zero-footprint-client-dicom-viewer-quick-start.pdf -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\files\ge-pacs-universal-viewer-zero-footprint-client-dicom-viewer-quick-start.pdf
# ok           html_raw     https://www.todaysmedicaldevelopments.com/ge-healthcare-image-viewer-oncology-113012.aspx -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\web pages\ge-healthcare-image-viewer-oncology-113012.aspx.html
# ok           html_raw     https://www.itnonline.com/content/ge-launches-emrpacs-integrated-website -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\web pages\ge-launches-emrpacs-integrated-website.html
# ok           file         https://www.gehealthcare.com/-/media/09f7b5678aaa42d4ba9f3df59ea0fb07.pdf?la=en&hash=22CAE8E96EBF4C89D3EFAB1F1B495972CA8971FE -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\files\healthcare-it-Universal-Viewer-Power-of-One-Brochure-JB52859XX2.pdf
# ok           html_raw     https://www.gehealthcare.com/about/newsroom/press-releases/ge-healthcare-highlights-new-solutions-including-ai-enabled-innovations-to-drive-precision-care-at-rsna-2024 -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\web pages\ge-healthcare-highlights-new-solutions-including-ai-enabled-innovations-to-drive-precision-care-at-rsna-2024.html
# ok           file         https://www.accessdata.fda.gov/cdrh_docs/pdf12/K121387.pdf -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\files\K121387.pdf
# ok           file         https://www.brighamandwomens.org/assets/BWH/radiology/pdfs/pacs-centricity-ra-for-medical-students.pdf -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\files\pacs-centricity-ra-for-medical-students.pdf
# ok           html_raw     https://www.gehealthcare.fr/products/healthcare-it/true-pacs -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\web pages\true-pacs.html
# ok           html_raw     https://global-medica.com/en/product/centricity-universal-viewer-pacs/ -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\web pages\centricity-universal-viewer-pacs.html
# ok           html_raw     https://github.com/GE-Healthcare-Centricity-PACS -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\web pages\GE-Healthcare-Centricity-PACS.html
# ok           html_raw     https://www.medequal.com/site/ge-pacs/ -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\web pages\ge-pacs.html
# ok           html_raw     https://www.diagnosticimaging.com/view/ge-explore-digital-x-rays-potential-new-flat-panel-chest-system -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\web pages\ge-explore-digital-x-rays-potential-new-flat-panel-chest-system.html
# ok           html_raw     https://www.gehealthcare.fr/products/centricity-uv -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\web pages\centricity-uv.html
# ok           html_raw     https://www.ge.com/news/press-releases/ge-healthcare-showcases-universal-viewer-connecting-advanced-3d-oncology-and-breast -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\web pages\ge-healthcare-showcases-universal-viewer-connecting-advanced-3d-oncology-and-breast.html
# ok           html_raw     https://xrayinterpreter.com/fda/K182419 -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\web pages\K182419.html
# ok           file         https://www.gehealthcare.com.au/-/media/7c1484d927314b1ab5f5c15070d3f05a.pdf?la=en-au -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\files\ip-app-library-gehealthcare-education-tip-app-library_ct-aw-hanging-protocol-quickstep_pdf.pdf
# ok           file         https://ansm.sante.fr/uploads/2024/10/28/20241028-mes-pacs-centricity-ge-healthcare.pdf -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\files\20241028-mes-pacs-centricity-ge-healthcare.pdf
# ...
# ok           html_raw     https://fhir.epic.com/Documentation -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\web pages\Documentation.html
# ok           file         https://www.agfahealthcare.com/wp-content/uploads/2025/04/001679_Enterprise_Imaging_8.4.x_DICOM_Conformance_Statement-5.pdf -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\files\001679_Enterprise_Imaging_8.4.x_DICOM_Conformance_Statement-5.pdf
# ok           html_raw     https://ansm.sante.fr/informations-de-securite/pacs-centricity-universal-viewer-zero-footprint-client-ge-healthcare-2 -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\web pages\pacs-centricity-universal-viewer-zero-footprint-client-ge-healthcare-2.html
# ok           html_raw     https://invent.ge/4iGfMfW -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\web pages\4iGfMfW.html
# ok           html_raw     https://www.medequal.com/site/ge-vna/ -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\web pages\ge-vna.html
# ok           html_raw     https://www.itnonline.com/content/ge-launches-radiology-diagnostic-reporting-solution-speech-recognition -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\web pages\ge-launches-radiology-diagnostic-reporting-solution-speech-recognition.html
# ok           file         http://docs.media.bitpipe.com/io_12x/io_121372/item_1091417/Universal%20Viewer%20Breast%20Imaging%20Webinar%20Deck%202014.pdf -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\files\Universal%20Viewer%20Breast%20Imaging%20Webinar%20Deck%202014.pdf
# ok           html_raw     https://aws.amazon.com/marketplace/pp/prodview-thchsttlpbn44 -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\web pages\prodview-thchsttlpbn44.html
# failed       -            https://pmc.ncbi.nlm.nih.gov/articles/PMC3473567/ -> None
# ok           file         https://www.gehealthcare.ru/-/media/gehc/us/images/products/healthcare-it/centricity-universal-viewer/redesign/improving-breast-imaging-workflow-efficiencies-whitepaper.pdf?rev=-1 -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\files\improving-breast-imaging-workflow-efficiencies-whitepaper.pdf
# failed       -            https://www.auntminnie.com/imaging-informatics/enterprise-imaging/pacs-vna/article/15593649/integrating-cad-with-pacs-adds-clinical-value -> None
# ok           html_raw     https://www.gehealthcare.com/about/newsroom/press-releases/ge-healthcare-delivers-advanced-speech-understanding-pacs?npclid=botnpclid -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\web pages\ge-healthcare-delivers-advanced-speech-understanding-pacs.html
# ok           html_raw     https://www.slideshare.net/slideshow/centricity-precision-reporting-pacs-brochure/11888741 -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\web pages\11888741.html
# ok           html_raw     https://www.itnonline.com/content/claron-showcases-nil-zero-footprint-universal-mammography-viewer-ecr -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\web pages\claron-showcases-nil-zero-footprint-universal-mammography-viewer-ecr.html
# ok           file         https://www.gehealthcare.com/en-my/-/jssmedia/global/products/files/healthcare-digital/centricity-universal-viewer/healthcare-it-centricity-universal-viewer-breast-imaging-brochure-jb59061us.pdf?rev=-1&hash=DA32C5FB92AF0D9B78CF305987A2437E -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\files\healthcare-it-Centricity-Universal-Viewer-Breast-Imaging-Brochure-JB59061US.pdf
# ok           file         https://ansm.sante.fr/uploads/2021/04/22/mes-190125-pacscentricity-ge.pdf -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\files\mes-190125-pacscentricity-ge.pdf
# ok           html_raw     https://www.canhealth.com/2021/08/11/ge-introduces-cloud-based-pacs-for-imaging/ -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\web pages\ge-introduces-cloud-based-pacs-for-imaging.html
# ok           file         https://www.khidi.or.kr/kohes/fileDownload?titleId=442145&fileId=1&fileDownType=C -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\files\khidisemina_20040716131941_PACS_RIS_Integration_using_HL7.pdf
# ok           file         https://www.accessdata.fda.gov/cdrh_docs/pdf11/k110875.pdf -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\files\k110875.pdf
# ok           html_raw     https://fda.report/PMN/K150420 -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\web pages\K150420.html
# ok           file         https://medicalpolicy.bcbstx.com/content/dam/bcbs/medicalpolicy/pdf/radiology/RAD601.046_2025-01-01.pdf -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\files\RAD601.046_2025-01-01.pdf
# ok           html_raw     https://www.massdevice.com/fda-releases-may-2011-510k-clearances/ -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\web pages\fda-releases-may-2011-510k-clearances.html
# ok           html_raw     https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpmn/pmn.cfm?ID=K150420 -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\web pages\pmn.cfm.html
# ok           html_raw     https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfres/res.cfm?id=194640 -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\web pages\res.cfm.html
# ok           file         https://www.accessdata.fda.gov/cdrh_docs/pdf15/K150420.pdf -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\files\K150420.pdf
# ok           html_raw     https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfres/res.cfm?id=195318 -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\web pages\res.cfm.html
# ok           html_raw     https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfRES/res.cfm?start_search=1&knumber=K150420 -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\web pages\res.cfm.html
# ok           html_raw     https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfres/res.cfm?id=193556 -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\web pages\res.cfm.html
# ok           html_raw     https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfRes/res.cfm?id=173302 -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\web pages\res.cfm.html
# ok           file         https://care.commonspirit.org/rs/938-HDH-552/images/GE-PACS-v6.0-SP7.1-Installation-Instructions.pdf?version=0 -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\files\GE-PACS-v6.0-SP7.1-Installation-Instructions.pdf
# ok           file         https://www.gehealthcare.com/-/jssmedia/documents/us-global/products/interoperability/hl7/gehc-hl7-conformance_enterprisearchive-v8_doc2512673_rev2.pdf?rev=-1&hash=0931F95E432AF3E8D94D666E767C6100 -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\files\GEHC-HL7-Conformance_EnterpriseArchive-v8_DOC2512673_Rev2.pdf
# failed       -            https://www.stonybrookmedicine.edu/sites/default/files/ZFP_QUICK_START_JA_DOC2268361%20(13 -> None
# failed       -            https://triangle-octagon-8fxh.squarespace.com/s/Artificial-Intelligence-and-Machine-Learning-AIML-Enabled-Medical-Devices-FDA.xlsx -> None
# ok           html_raw     https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfres/res.cfm?id=117004 -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\web pages\res.cfm.html
# failed       -            https://www.auntminnie.com/imaging-informatics/enterprise-imaging/pacs-vna/article/15594452/ge-introduces-updated-enterprise-archive-at-himss -> None
# ok           html_raw     https://www.scribd.com/document/945812149/Centricity-Universal-Viewer-Version-7-0-SP7-0-0-1-User-Manual -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\web pages\Centricity-Universal-Viewer-Version-7-0-SP7-0-0-1-User-Manual.html
# ok           html_raw     https://medicaldevices.icij.org/devices/usa-radiology-devices-centricity-enterprise-archive -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\web pages\usa-radiology-devices-centricity-enterprise-archive.html
# ok           html_raw     https://www.dicardiology.com/sites/default/files/files/charts/2024%20PACS_Web.csv -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\web pages\2024%20PACS_Web.csv.html
# ok           html_raw     https://www.youtube.com/watch?v=Kl3LD2J_fwQ -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\web pages\watch.html
# ok           html_raw     https://www.gehealthcare.com/products/software/enterprise-imaging -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\web pages\enterprise-imaging.html
# ok           file         https://www.gehealthcare.com/-/media/cf42b0e0a94c478c988957f4278162bb.pdf?la=en-us -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\files\GEHC-SP_SIGNA-VOYAGER_8-270F.pdf
# ok           html_raw     https://www.scribd.com/document/763123476/Brochure-GE-Centricity-PACS -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\web pages\Brochure-GE-Centricity-PACS.html
# ok           html_raw     https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfRES/res.cfm?id=186461 -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\web pages\res.cfm.html
# ok           html_raw     https://www.slideshare.net/slideshow/centricity-pacs-iw-brochure/11805264 -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\web pages\11805264.html
# ok           file         https://www.gehealthcare.fr/-/jssmedia/gehc/us/images/products/radiography/definium-pace-select-et/definiumpaceselect_et_brochure_uscan_v2.pdf?rev=-1 -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\files\DefiniumPaceSelect_ET_Brochure_USCAN_v2.pdf
# ok           html_raw     https://www.youtube.com/watch?v=bbF8CZK-bVs -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\web pages\watch.html
# ok           file         https://resources.wisdominterface.com/wp-content/uploads/2024/03/Centricity-Cardio-Enterprise_CardiologySolutionGuide_JB27511XX.pdf -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\files\Centricity-Cardio-Enterprise_CardiologySolutionGuide_JB27511XX.pdf
# ok           html_raw     https://www.gehealthcare.co.uk/products/healthcare-it/enterprise-imaging -> C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\web pages\enterprise-imaging.html
# failed       -            https://www.lablue.com/-/media/Medical%20Policies/2020/08/03/17/33/Dynamic%20Spinal%20Visualization%20and%20Vertebral%20Motion%20Analysis%20CC%2000197%2020190320_accessible%20pdf.pdf -> None
# failed       -            https://mkp.gem.gov.in/catalog_data/catalog_support_document/buyer_documents/1559527/54/78/703/CatalogAttrs/SpecificationDocument/2022/11/29/tenderspec-28nov2022_2022-11-29-17-04-36_8acfa98bda9b58d1282d9bcaabd3e0f6.pdf -> None
#
# Done in 133.22s. Manifest: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\fetch_manifest.json

# %%
a=2

# %%
from playwright.sync_api import sync_playwright
