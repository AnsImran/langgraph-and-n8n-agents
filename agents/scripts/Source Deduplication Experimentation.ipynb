# %% [markdown]
# ### PACS Viewers

# %%
"""
Overview
--------
This script scans vendor subfolders that contain an `original sources.txt`, extracts
all links in those files, and produces:
  - dictionary1.json: every link with metadata such as positions, normalized form,
    and duplicate lists.
  - deduplicated.json: only one representative per normalized (bare) URL.

Goals and fit
-------------
- Normalize and de-duplicate links coming from many LLM outputs with inconsistent
  formatting (markdown links, raw URLs, emphasized links, etc.).
- Provide deterministic selection of one link per duplicate group (first occurrence).
- Leave summaries empty in this variant; a separate script handles summary-aware
  selection.

Usage
-----
    python deduplicate_sources.py [--data-dir .]

Key behaviors
-------------
- Character positions are 0-based; end positions are inclusive.
- Duplicate grouping is driven by a normalized "bare minimum" URL
  (scheme/`www` stripped, default ports dropped, tracking params removed, aliases
  applied).
"""

from __future__ import annotations

import argparse
import json
import random
import re
from collections import defaultdict
from pathlib import Path
from urllib.parse import urlparse

LINK_PATTERN = re.compile(r"\[(?P<link_text>[^\]]+)\]\((?P<link_target>[^)]+)\)")
# Raw URL pattern captures:
# - explicit schemes (http/https)
# - www.* domains
# - bare domains with a path (e.g., example.com/foo)
RAW_URL_PATTERN = re.compile(
    r"""
    (?P<url>
        (?:https?://|www\.)[^\s)]+
        |
        [a-zA-Z0-9.-]+\.[a-zA-Z]{2,}(?:/[^\s)]*)?
    )
    """,
    re.VERBOSE,
)


def normalize_url(url: str) -> str:
    """Return a bare-minimum form of the URL for duplicate detection."""
    # Clean markdown emphasis and trailing punctuation.
    candidate = url.strip()
    # Strip surrounding markdown emphasis characters (e.g., **url** or *url*)
    candidate = re.sub(r"^[*_]+", "", candidate)
    candidate = re.sub(r"[*_]+$", "", candidate)
    # Strip trailing punctuation that often trails links
    candidate = candidate.rstrip(").,;")
    # Ensure a scheme exists for urlparse.
    if not re.match(r"^[a-zA-Z][a-zA-Z0-9+.-]*://", candidate):
        candidate = f"http://{candidate}"

    # Parse and normalize host/path/query.
    try:
        parsed = urlparse(candidate)
    except ValueError:
        # Handle malformed URLs (e.g., stray brackets) by stripping brackets and retrying.
        candidate_fallback = candidate.strip("[]")
        try:
            parsed = urlparse(candidate_fallback)
        except ValueError:
            # If still invalid, return the cleaned candidate as-is to avoid crashes.
            return candidate_fallback
    netloc = parsed.netloc.lower()

    if netloc.startswith("www."):
        netloc = netloc[4:]

    # Host aliases (add more as needed)
    host_aliases = {
        "agfa.com": "agfahealthcare.com",
        "www.agfa.com": "agfahealthcare.com",
    }
    netloc = host_aliases.get(netloc, netloc)

    if netloc.endswith(":80"):
        netloc = netloc[: -len(":80")]
    if netloc.endswith(":443"):
        netloc = netloc[: -len(":443")]

    # Normalize path (collapse duplicate slashes, drop trailing slash).
    path = re.sub(r"/{2,}", "/", parsed.path or "").rstrip("/")

    # Strip tracking params and fragments
    tracking_prefixes = ("utm_", "fbclid", "gclid", "mc_cid", "mc_eid", "vero_id")
    query_pairs = []
    if parsed.query:
        for key, value in [q.split("=", 1) if "=" in q else (q, "") for q in parsed.query.split("&") if q]:
            if key.startswith(tracking_prefixes):
                continue
            query_pairs.append((key, value))
    query = "&".join(f"{k}={v}" if v else k for k, v in query_pairs)

    normalized = netloc + path
    if query:
        normalized = f"{normalized}?{query}"

    return normalized


def extract_summary(text: str, start: int, end: int) -> str:
    """Placeholder: summaries are intentionally not extracted in this variant."""
    return ""


def build_dictionary1(text: str) -> dict[str, dict]:
    """Parse one `original sources.txt` into dictionary1 entries with metadata."""
    dictionary1: dict[str, dict] = {}

    # First, capture markdown links ([text](url)); use the target as the original form.
    md_matches = list(LINK_PATTERN.finditer(text))
    entries: list[dict] = []
    occupied_ranges: list[tuple[int, int]] = []

    for match in md_matches:
        # Store the link target and mark both target and link-text spans as occupied.
        original_form = match.group("link_target").strip()
        start_pos = match.start("link_target")
        end_pos = match.end("link_target") - 1  # inclusive
        occupied_ranges.append((start_pos, end_pos))
        occupied_ranges.append((match.start("link_text"), match.end("link_text") - 1))
        entries.append(
            {
                "original form": original_form,
                "start": start_pos,
                "end": end_pos,
            }
        )

    # Next, capture raw URLs not already covered by markdown link targets.
    def overlaps(span: tuple[int, int]) -> bool:
        return any(not (span[1] < s or span[0] > e) for s, e in occupied_ranges)

    for match in RAW_URL_PATTERN.finditer(text):
        start_pos = match.start("url")
        end_pos = match.end("url") - 1
        if overlaps((start_pos, end_pos)):
            continue
        # Record raw URL and mark its span.
        original_form = match.group("url").strip()
        entries.append(
            {
                "original form": original_form,
                "start": start_pos,
                "end": end_pos,
            }
        )
        occupied_ranges.append((start_pos, end_pos))

    # Sort by position to keep deterministic link numbering.
    entries.sort(key=lambda x: x["start"])

    # Precompute bare forms for grouping.
    for entry in entries:
        entry["bare"] = normalize_url(entry["original form"])

    for idx, entry in enumerate(entries):
        link_key = f"link{idx + 1}"
        dictionary1[link_key] = {
            "duplicate list": [],
            "original form": entry["original form"],
            "bare minimum form": entry["bare"],
            "original start position of the current link": entry["start"],
            "original end position of the current link": entry["end"],
            "accompanying RAG summary + metadata string": "",
            "selected": 0,
        }

    return dictionary1


def mark_duplicates(dictionary1: dict[str, dict]) -> dict[str, dict]:
    """Fill duplicate lists and select the first-occurring representative per bare URL."""
    groups: dict[str, list[str]] = defaultdict(list)
    for key, payload in dictionary1.items():
        groups[payload["bare minimum form"]].append(key)

    for members in groups.values():
        if len(members) == 1:
            continue
        # Populate duplicate lists for members in the same group.
        for key in members:
            dictionary1[key]["duplicate list"] = [m for m in members if m != key]

    for members in groups.values():
        # Select the first occurrence (deterministic, based on document order)
        winner = members[0]
        for key in members:
            dictionary1[key]["selected"] = 1 if key == winner else 0

    return dictionary1


def build_dictionary2(dictionary1: dict[str, dict]) -> dict[str, dict]:
    """Return only the selected entries."""
    return {k: v for k, v in dictionary1.items() if v.get("selected") == 1}


def process_file(path: Path) -> tuple[dict[str, dict], dict[str, dict]]:
    """
    Parse one `original sources.txt`, de-duplicate links, and return both dictionaries.
    """
    text = path.read_text(encoding="utf-8", errors="replace")
    dictionary1 = build_dictionary1(text)
    dictionary1 = mark_duplicates(dictionary1)
    dictionary2 = build_dictionary2(dictionary1)
    return dictionary1, dictionary2


def save_output(path: Path, dictionary1: dict[str, dict], dictionary2: dict[str, dict]) -> None:
    """
    Write dictionary1.json and deduplicated.json next to the source file, with meta counts.
    """
    output1 = path.with_name("dictionary1.json")
    output2 = path.with_name("deduplicated.json")
    output1.write_text(json.dumps(dictionary1, indent=2), encoding="utf-8")
    output2.write_text(json.dumps(dictionary2, indent=2), encoding="utf-8")



# Set the base directory that contains vendor subfolders.
base_dir = Path(r"C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers")  # change if needed, e.g., Path("data") or Path(r"C:\path\to\PACS Viewers")

source_files = list(base_dir.glob("*/original sources.txt"))
if not source_files:
    raise SystemExit("No 'original sources.txt' files found under the provided data directory.")

for src in source_files:
    print(f"Processing {src} ...")
    d1, d2 = process_file(src)
    save_output(src, d1, d2)
    print(f"  links found: {len(d1)} | deduplicated: {len(d2)} | output: {src.with_name('deduplicated.json')}")
# Out:
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\1. agfahealthcare.com, [AGFA HealthCare Enterprise Imaging], PACS  Diagnostic Imaging Viewer\original sources.txt ...
#   links found: 317 | deduplicated: 162 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\1. agfahealthcare.com, [AGFA HealthCare Enterprise Imaging], PACS  Diagnostic Imaging Viewer\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\10. candelis.com, Candelis ImageGrid PACS, PACS - Diagnostic Imaging Viewer\original sources.txt ...
#   links found: 341 | deduplicated: 192 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\10. candelis.com, Candelis ImageGrid PACS, PACS - Diagnostic Imaging Viewer\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\11. coactiv.com, CoActiv EXAM-PACS, PACS - Diagnostic Imaging Viewer, CoActiv EXAM-PACS, PACS - Diagnostic Imaging Viewer\original sources.txt ...
#   links found: 213 | deduplicated: 90 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\11. coactiv.com, CoActiv EXAM-PACS, PACS - Diagnostic Imaging Viewer, CoActiv EXAM-PACS, PACS - Diagnostic Imaging Viewer\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\12. delmedical.com, [DEL MEDICAL EvoView PACS], PACS - Diagnostic Imaging Viewer\original sources.txt ...
#   links found: 98 | deduplicated: 51 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\12. delmedical.com, [DEL MEDICAL EvoView PACS], PACS - Diagnostic Imaging Viewer\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\13. icrco.com, [iCRco Clarity PACS], PACS - Diagnostic Imaging Viewer\original sources.txt ...
#   links found: 171 | deduplicated: 98 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\13. icrco.com, [iCRco Clarity PACS], PACS - Diagnostic Imaging Viewer\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\14. corestudycast.com, Studycast (Core Sound Imaging), PACS - Diagnostic Imaging Viewer\original sources.txt ...
#   links found: 241 | deduplicated: 127 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\14. corestudycast.com, Studycast (Core Sound Imaging), PACS - Diagnostic Imaging Viewer\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\15. emsow.com, Imaging Wave EMSOW (EMSOW RadAlly), PACS - Diagnostic Imaging Viewer\original sources.txt ...
#   links found: 171 | deduplicated: 95 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\15. emsow.com, Imaging Wave EMSOW (EMSOW RadAlly), PACS - Diagnostic Imaging Viewer\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\16. mi.medical.canon, [Canon Vitrea Advanced Visualization], PACS - Diagnostic Imaging Viewer, [Canon Vitrea Advanced Visualization], PACS - Diagnostic Imaging Viewer\original sources.txt ...
#   links found: 189 | deduplicated: 107 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\16. mi.medical.canon, [Canon Vitrea Advanced Visualization], PACS - Diagnostic Imaging Viewer, [Canon Vitrea Advanced Visualization], PACS - Diagnostic Imaging Viewer\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\17. terarecon.com, [TeraRecon iNtuition], PACS - Diagnostic Imaging Viewer\original sources.txt ...
#   links found: 154 | deduplicated: 83 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\17. terarecon.com, [TeraRecon iNtuition], PACS - Diagnostic Imaging Viewer\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\18. siemens-healthineers.com, [Siemens syngo.via - Syngo Carbon], PACS - Diagnostic Imaging Viewer\original sources.txt ...
#   links found: 364 | deduplicated: 103 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\18. siemens-healthineers.com, [Siemens syngo.via - Syngo Carbon], PACS - Diagnostic Imaging Viewer\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\19. ziosoftinc.com, Ziosoft Ziostation (Ziostation2 - Ziostation REVORAS), PACS - Diagnostic Imaging Viewer\original sources.txt ...
#   links found: 207 | deduplicated: 118 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\19. ziosoftinc.com, Ziosoft Ziostation (Ziostation2 - Ziostation REVORAS), PACS - Diagnostic Imaging Viewer\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\original sources.txt ...
#   links found: 337 | deduplicated: 235 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\2. gehealthcare.com, [GE HealthCare True PACS (formerly Centricity PACS)], PACS - Diagnostic Imaging Viewer\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\20. mirada-medical.com, Mirada XD, PACS - Diagnostic Imaging Viewer\original sources.txt ...
#   links found: 188 | deduplicated: 88 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\20. mirada-medical.com, Mirada XD, PACS - Diagnostic Imaging Viewer\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\21. radlogics.com, RADLogics AlphaPoint Imaging Software, PACS-Diagnostic Imaging Viewer\original sources.txt ...
#   links found: 131 | deduplicated: 83 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\21. radlogics.com, RADLogics AlphaPoint Imaging Software, PACS-Diagnostic Imaging Viewer\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\22. mimsoftware.com, [MIM Encore™ (MIM Software)], PACS-Diagnostic Imaging Viewer\original sources.txt ...
#   links found: 321 | deduplicated: 205 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\22. mimsoftware.com, [MIM Encore™ (MIM Software)], PACS-Diagnostic Imaging Viewer\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\23. hermesmedical.com, [Hermes Medical Solutions – Affinity (Hermia Software Suite)], PACS-Diagnostic Imaging Viewer\original sources.txt ...
#   links found: 232 | deduplicated: 127 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\23. hermesmedical.com, [Hermes Medical Solutions – Affinity (Hermia Software Suite)], PACS-Diagnostic Imaging Viewer\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\24. segamicorp.com, Segami Oasis, PACS-Diagnostic Imaging Viewer\original sources.txt ...
#   links found: 276 | deduplicated: 162 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\24. segamicorp.com, Segami Oasis, PACS-Diagnostic Imaging Viewer\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\25. medisimaging.com, Medis Suite MR, PACS - Diagnostic Imaging Viewer\original sources.txt ...
#   links found: 293 | deduplicated: 200 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\25. medisimaging.com, Medis Suite MR, PACS - Diagnostic Imaging Viewer\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\26. olea-medical.com, [Olea Sphere (Olea Medical)], PACS - Diagnostic Imaging Viewer\original sources.txt ...
#   links found: 263 | deduplicated: 147 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\26. olea-medical.com, [Olea Sphere (Olea Medical)], PACS - Diagnostic Imaging Viewer\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\27. nordicneurolab.com, [nordicICE], PACS - Diagnostic Imaging Viewer\original sources.txt ...
#   links found: 206 | deduplicated: 132 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\27. nordicneurolab.com, [nordicICE], PACS - Diagnostic Imaging Viewer\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\28. brainlab.com, [Brainlab (Elements Viewer - Elements DICOM Viewer Web-based - Quentry)], PACS - Diagnostic Imaging Viewer\original sources.txt ...
#   links found: 150 | deduplicated: 92 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\28. brainlab.com, [Brainlab (Elements Viewer - Elements DICOM Viewer Web-based - Quentry)], PACS - Diagnostic Imaging Viewer\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\29. visiblepatient.com, [Visible Patient], PACS - Diagnostic Imaging Viewer\original sources.txt ...
#   links found: 186 | deduplicated: 109 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\29. visiblepatient.com, [Visible Patient], PACS - Diagnostic Imaging Viewer\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\3. usa.philips.com, Philips Vue PACS, PACS - Diagnostic Imaging Viewer\original sources.txt ...
#   links found: 153 | deduplicated: 90 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\3. usa.philips.com, Philips Vue PACS, PACS - Diagnostic Imaging Viewer\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\30. usa.philips.com, Philips IntelliSpace Cardiovascular, PACS - Diagnostic Imaging Viewer\original sources.txt ...
#   links found: 133 | deduplicated: 82 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\30. usa.philips.com, Philips IntelliSpace Cardiovascular, PACS - Diagnostic Imaging Viewer\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\31. gehealthcare.com, [GE EchoPAC], PACS - Diagnostic Imaging Viewer\original sources.txt ...
#   links found: 140 | deduplicated: 73 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\31. gehealthcare.com, [GE EchoPAC], PACS - Diagnostic Imaging Viewer\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\32. ultralinq.com, [UltraLinq]  PACS - Diagnostic Imaging Viewer\original sources.txt ...
#   links found: 232 | deduplicated: 118 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\32. ultralinq.com, [UltraLinq]  PACS - Diagnostic Imaging Viewer\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\33. ziehm.com, [Ziehm mini PACS solution], PACS - Diagnostic Imaging Viewer\original sources.txt ...
#   links found: 20 | deduplicated: 14 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\33. ziehm.com, [Ziehm mini PACS solution], PACS - Diagnostic Imaging Viewer\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\34. hologic.com, [Hologic mini PACS solution], PACS - Diagnostic Imaging Viewer\original sources.txt ...
#   links found: 103 | deduplicated: 72 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\34. hologic.com, [Hologic mini PACS solution], PACS - Diagnostic Imaging Viewer\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\35. hologic.com, [Hologic SecurView DX], PACS - Diagnostic Imaging Viewer\original sources.txt ...
#   links found: 124 | deduplicated: 67 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\35. hologic.com, [Hologic SecurView DX], PACS - Diagnostic Imaging Viewer\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\36. gehealthcare.com, GE Seno Advantage - Seno Iris, PACS - Diagnostic Imaging Viewer\original sources.txt ...
#   links found: 107 | deduplicated: 70 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\36. gehealthcare.com, GE Seno Advantage - Seno Iris, PACS - Diagnostic Imaging Viewer\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\37. threepalmsoft.com, [Three Palm WorkstationOne], PACS - Diagnostic Imaging Viewer\original sources.txt ...
#   links found: 140 | deduplicated: 70 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\37. threepalmsoft.com, [Three Palm WorkstationOne], PACS - Diagnostic Imaging Viewer\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\38. business.optum.com, [Conserus Mammo Viewer (Change Healthcare)], PACS - Diagnostic Imaging Viewer\original sources.txt ...
#   links found: 131 | deduplicated: 107 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\38. business.optum.com, [Conserus Mammo Viewer (Change Healthcare)], PACS - Diagnostic Imaging Viewer\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\39. infinittna.com, INFINITT PACS, PACS - Diagnostic Imaging Viewer\original sources.txt ...
#   links found: 219 | deduplicated: 101 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\39. infinittna.com, INFINITT PACS, PACS - Diagnostic Imaging Viewer\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\4. healthcaresolutions-us.fujifilm.com, [FUJIFILM Synapse PACS], PACS - Diagnostic Imaging Viewer\original sources.txt ...
#   links found: 174 | deduplicated: 88 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\4. healthcaresolutions-us.fujifilm.com, [FUJIFILM Synapse PACS], PACS - Diagnostic Imaging Viewer\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\40. healthcare.konicaminolta.us, Konica Minolta Exa Enterprise Imaging (Exa Platform - EXA), PACS - Diagnostic Imaging Viewer\original sources.txt ...
#   links found: 219 | deduplicated: 140 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\40. healthcare.konicaminolta.us, Konica Minolta Exa Enterprise Imaging (Exa Platform - EXA), PACS - Diagnostic Imaging Viewer\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\41. paxerahealth.com, [PaxeraHealth PaxeraUltima - Paxera PACS], PACS - Diagnostic Imaging Viewer\original sources.txt ...
#   links found: 117 | deduplicated: 70 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\41. paxerahealth.com, [PaxeraHealth PaxeraUltima - Paxera PACS], PACS - Diagnostic Imaging Viewer\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\42. ramsoft.com, RamSoft PowerServer - OmegaAI, PACS - Diagnostic Imaging Viewer\original sources.txt ...
#   links found: 233 | deduplicated: 136 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\42. ramsoft.com, RamSoft PowerServer - OmegaAI, PACS - Diagnostic Imaging Viewer\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\43. scimage.com, [ScImage PICOM365], PACS - Diagnostic Imaging Viewer\original sources.txt ...
#   links found: 165 | deduplicated: 89 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\43. scimage.com, [ScImage PICOM365], PACS - Diagnostic Imaging Viewer\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\44. promed.com.au, [Visage 7 Enterprise Viewer], PACS - Diagnostic Imaging Viewer\original sources.txt ...
#   links found: 165 | deduplicated: 87 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\44. promed.com.au, [Visage 7 Enterprise Viewer], PACS - Diagnostic Imaging Viewer\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\45. osirix-viewer.com, [OsiriX MD], PACS - Diagnostic Imaging Viewer\original sources.txt ...
#   links found: 192 | deduplicated: 91 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\45. osirix-viewer.com, [OsiriX MD], PACS - Diagnostic Imaging Viewer\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\46. documentation.clearcanvas.ca, [ClearCanvas RIS-PACS], PACS - Diagnostic Imaging Viewer\original sources.txt ...
#   links found: 184 | deduplicated: 98 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\46. documentation.clearcanvas.ca, [ClearCanvas RIS-PACS], PACS - Diagnostic Imaging Viewer\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\47. onepacs.com, [OnePACS], PACS - Diagnostic Imaging Viewer\original sources.txt ...
#   links found: 203 | deduplicated: 121 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\47. onepacs.com, [OnePACS], PACS - Diagnostic Imaging Viewer\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\48. purview.net, [Purview Image], PACS - Diagnostic Imaging Viewer\original sources.txt ...
#   links found: 190 | deduplicated: 91 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\48. purview.net, [Purview Image], PACS - Diagnostic Imaging Viewer\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\49. intelerad.com, [Ambra Health (Intelerad InteleShare - Ambra PACS - ProViewer)], PACS - Diagnostic Imaging Viewer\original sources.txt ...
#   links found: 153 | deduplicated: 89 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\49. intelerad.com, [Ambra Health (Intelerad InteleShare - Ambra PACS - ProViewer)], PACS - Diagnostic Imaging Viewer\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\5. merative.com, [Merge PACS (Merative)], PACS - Diagnostic Imaging Viewer\original sources.txt ...
#   links found: 291 | deduplicated: 176 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\5. merative.com, [Merge PACS (Merative)], PACS - Diagnostic Imaging Viewer\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\50. erad.com, eRAD PACS, PACS - Diagnostic Imaging Viewer\original sources.txt ...
#   links found: 187 | deduplicated: 92 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\50. erad.com, eRAD PACS, PACS - Diagnostic Imaging Viewer\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\51. lifetrackmed.com, [Lifetrack PACS], PACS - Diagnostic Imaging Viewer\original sources.txt ...
#   links found: 161 | deduplicated: 79 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\51. lifetrackmed.com, [Lifetrack PACS], PACS - Diagnostic Imaging Viewer\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\52. iq-image.com, [Plum iQ-4CLOUD], PACS - Diagnostic Imaging Viewer\original sources.txt ...
#   links found: 122 | deduplicated: 72 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\52. iq-image.com, [Plum iQ-4CLOUD], PACS - Diagnostic Imaging Viewer\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\53. vepro.com, Vepro PACS, PACS - Diagnostic Imaging Viewer\original sources.txt ...
#   links found: 136 | deduplicated: 72 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\53. vepro.com, Vepro PACS, PACS - Diagnostic Imaging Viewer\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\54. intellirad.com.au, [Voyager PACS], PACS - Diagnostic Imaging Viewer\original sources.txt ...
#   links found: 128 | deduplicated: 86 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\54. intellirad.com.au, [Voyager PACS], PACS - Diagnostic Imaging Viewer\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\55. sironamedical.com, [Sirona Advanced Imaging Suite], PACS - Diagnostic Imaging Viewer\original sources.txt ...
#   links found: 174 | deduplicated: 114 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\55. sironamedical.com, [Sirona Advanced Imaging Suite], PACS - Diagnostic Imaging Viewer\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\6. medical.sectra.com, Sectra PACS (Sectra Workstation IDS7 diagnostic viewer), PACS - Diagnostic Imaging Viewer\original sources.txt ...
#   links found: 218 | deduplicated: 120 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\6. medical.sectra.com, Sectra PACS (Sectra Workstation IDS7 diagnostic viewer), PACS - Diagnostic Imaging Viewer\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\7. paxerahealth.com, [PaxeraHealth PaxeraUltima], PACS - Diagnostic Imaging Viewer\original sources.txt ...
#   links found: 180 | deduplicated: 109 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\7. paxerahealth.com, [PaxeraHealth PaxeraUltima], PACS - Diagnostic Imaging Viewer\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\8. novarad.net, Novarad NovaPACS, PACS - Diagnostic Imaging Viewer\original sources.txt ...
#   links found: 182 | deduplicated: 99 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\8. novarad.net, Novarad NovaPACS, PACS - Diagnostic Imaging Viewer\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\9. avreo.com, Avreo interWORKS, PACS - Diagnostic Imaging Viewer\original sources.txt ...
#   links found: 156 | deduplicated: 74 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Viewers\9. avreo.com, Avreo interWORKS, PACS - Diagnostic Imaging Viewer\deduplicated.json

# %% [markdown]
# # AI Early Detection Softwares

# %%
# Set the base directory that contains vendor subfolders.
base_dir = Path(r"C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\AI Early Detection Softwares")  # change if needed, e.g., Path("data") or Path(r"C:\path\to\PACS Viewers")

source_files = list(base_dir.glob("*/original sources.txt"))
if not source_files:
    raise SystemExit("No 'original sources.txt' files found under the provided data directory.")

for src in source_files:
    print(f"Processing {src} ...")
    d1, d2 = process_file(src)
    save_output(src, d1, d2)
    print(f"  links found: {len(d1)} | deduplicated: {len(d2)} | output: {src.with_name('deduplicated.json')}")
# Out:
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\AI Early Detection Softwares\1. www.annalise.ai, Annalise Enterprise CXR\original sources.txt ...
#   links found: 223 | deduplicated: 83 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\AI Early Detection Softwares\1. www.annalise.ai, Annalise Enterprise CXR\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\AI Early Detection Softwares\10. www.nanox.ai, Nanox.AI (HealthFLD)\original sources.txt ...
#   links found: 280 | deduplicated: 165 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\AI Early Detection Softwares\10. www.nanox.ai, Nanox.AI (HealthFLD)\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\AI Early Detection Softwares\11. www.nanox.ai, Nanox.AI (HealthCCSng)\original sources.txt ...
#   links found: 218 | deduplicated: 104 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\AI Early Detection Softwares\11. www.nanox.ai, Nanox.AI (HealthCCSng)\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\AI Early Detection Softwares\2. www.azmed.co, AZmed (Rayvolve)\original sources.txt ...
#   links found: 196 | deduplicated: 99 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\AI Early Detection Softwares\2. www.azmed.co, AZmed (Rayvolve)\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\AI Early Detection Softwares\3. www.gleamer.ai, Gleamer (Boneview)\original sources.txt ...
#   links found: 172 | deduplicated: 76 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\AI Early Detection Softwares\3. www.gleamer.ai, Gleamer (Boneview)\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\AI Early Detection Softwares\4. www.lunit.io, Lunit INSIGHT CXR\original sources.txt ...
#   links found: 150 | deduplicated: 68 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\AI Early Detection Softwares\4. www.lunit.io, Lunit INSIGHT CXR\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\AI Early Detection Softwares\5. www.rayscape.ai, Rayscape CXR\original sources.txt ...
#   links found: 116 | deduplicated: 71 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\AI Early Detection Softwares\5. www.rayscape.ai, Rayscape CXR\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\AI Early Detection Softwares\6. www.signalpet.com, SignalPET\original sources.txt ...
#   links found: 261 | deduplicated: 166 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\AI Early Detection Softwares\6. www.signalpet.com, SignalPET\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\AI Early Detection Softwares\7. www.arterys.com, Arterys Oncology DL\original sources.txt ...
#   links found: 230 | deduplicated: 170 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\AI Early Detection Softwares\7. www.arterys.com, Arterys Oncology DL\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\AI Early Detection Softwares\71. deephealth.com, DeepHealth, breast lesions & musculoskeletal anomalies on MRI\original sources.txt ...
#   links found: 279 | deduplicated: 176 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\AI Early Detection Softwares\71. deephealth.com, DeepHealth, breast lesions & musculoskeletal anomalies on MRI\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\AI Early Detection Softwares\72. gehealthcare.com, GE Healthcare VeriSound AI\original sources.txt ...
#   links found: 262 | deduplicated: 210 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\AI Early Detection Softwares\72. gehealthcare.com, GE Healthcare VeriSound AI\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\AI Early Detection Softwares\73. deephealth.com, DeepHealth, Support for anomaly detection in abdominal and vascular ultrasound\original sources.txt ...
#   links found: 229 | deduplicated: 162 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\AI Early Detection Softwares\73. deephealth.com, DeepHealth, Support for anomaly detection in abdominal and vascular ultrasound\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\AI Early Detection Softwares\74. healthcaresolutions-us.fujifilm.com, Fujifilm Synapse AI Orchestrator\original sources.txt ...
#   links found: 175 | deduplicated: 149 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\AI Early Detection Softwares\74. healthcaresolutions-us.fujifilm.com, Fujifilm Synapse AI Orchestrator\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\AI Early Detection Softwares\75. aidoc.com, Urgent findings like emboli during vascular fluoroscopy-guided procedures\original sources.txt ...
#   links found: 114 | deduplicated: 78 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\AI Early Detection Softwares\75. aidoc.com, Urgent findings like emboli during vascular fluoroscopy-guided procedures\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\AI Early Detection Softwares\76. radnet.com, RadNet AI for Breast\original sources.txt ...
#   links found: 276 | deduplicated: 186 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\AI Early Detection Softwares\76. radnet.com, RadNet AI for Breast\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\AI Early Detection Softwares\77. deephealth.com, DeepHealth (iCAD integration)\original sources.txt ...
#   links found: 308 | deduplicated: 194 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\AI Early Detection Softwares\77. deephealth.com, DeepHealth (iCAD integration)\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\AI Early Detection Softwares\78. gleamer.aisolutions, Gleamer AI Copilot X-ray (BoneView, ChestView) + CT (MSK, lung) + potential expansions via acquisitions (e.g., Pixyl for MRI)\original sources.txt ...
#   links found: 156 | deduplicated: 75 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\AI Early Detection Softwares\78. gleamer.aisolutions, Gleamer AI Copilot X-ray (BoneView, ChestView) + CT (MSK, lung) + potential expansions via acquisitions (e.g., Pixyl for MRI)\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\AI Early Detection Softwares\79. rayscape.ai, Rayscape Platform X-ray (CXR) + CT (lung) + MRI (prostate)\original sources.txt ...
#   links found: 255 | deduplicated: 174 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\AI Early Detection Softwares\79. rayscape.ai, Rayscape Platform X-ray (CXR) + CT (lung) + MRI (prostate)\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\AI Early Detection Softwares\8. www.contextflow.com, Contextflow ADVANCE Chest CT\original sources.txt ...
#   links found: 263 | deduplicated: 168 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\AI Early Detection Softwares\8. www.contextflow.com, Contextflow ADVANCE Chest CT\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\AI Early Detection Softwares\80. behold.ai — Red Dot\original sources.txt ...
#   links found: 301 | deduplicated: 120 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\AI Early Detection Softwares\80. behold.ai — Red Dot\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\AI Early Detection Softwares\81. riveraintech.com, Riverain Technologies — ClearRead Xray\original sources.txt ...
#   links found: 137 | deduplicated: 72 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\AI Early Detection Softwares\81. riveraintech.com, Riverain Technologies — ClearRead Xray\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\AI Early Detection Softwares\82. annalise.ai, Annalise.ai (CTB)\original sources.txt ...
#   links found: 257 | deduplicated: 148 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\AI Early Detection Softwares\82. annalise.ai, Annalise.ai (CTB)\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\AI Early Detection Softwares\83. riveraintech.com, Riverain — ClearRead CT\original sources.txt ...
#   links found: 138 | deduplicated: 74 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\AI Early Detection Softwares\83. riveraintech.com, Riverain — ClearRead CT\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\AI Early Detection Softwares\84. mirada-medical.com, Mirada Medical\original sources.txt ...
#   links found: 162 | deduplicated: 92 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\AI Early Detection Softwares\84. mirada-medical.com, Mirada Medical\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\AI Early Detection Softwares\85. hermesmedical.com, Hermes Medical Solutions\original sources.txt ...
#   links found: 203 | deduplicated: 116 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\AI Early Detection Softwares\85. hermesmedical.com, Hermes Medical Solutions\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\AI Early Detection Softwares\86. subtlemedical.com, Subtle Medical — SubtlePET\original sources.txt ...
#   links found: 190 | deduplicated: 93 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\AI Early Detection Softwares\86. subtlemedical.com, Subtle Medical — SubtlePET\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\AI Early Detection Softwares\87. icometrix.com, icometrix — icobrain\original sources.txt ...
#   links found: 234 | deduplicated: 117 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\AI Early Detection Softwares\87. icometrix.com, icometrix — icobrain\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\AI Early Detection Softwares\88. arterys.com, Arterys (Tempus)\original sources.txt ...
#   links found: 223 | deduplicated: 145 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\AI Early Detection Softwares\88. arterys.com, Arterys (Tempus)\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\AI Early Detection Softwares\89. koiosmedical.com, Koios Medical\original sources.txt ...
#   links found: 171 | deduplicated: 97 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\AI Early Detection Softwares\89. koiosmedical.com, Koios Medical\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\AI Early Detection Softwares\9. www.lunit.io, Lunit INSIGHT Chest CT\original sources.txt ...
#   links found: 170 | deduplicated: 140 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\AI Early Detection Softwares\9. www.lunit.io, Lunit INSIGHT Chest CT\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\AI Early Detection Softwares\90. ultromics.com, Ultromics — EchoGo\original sources.txt ...
#   links found: 83 | deduplicated: 54 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\AI Early Detection Softwares\90. ultromics.com, Ultromics — EchoGo\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\AI Early Detection Softwares\91. captionhealth.com, Caption Health\original sources.txt ...
#   links found: 167 | deduplicated: 107 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\AI Early Detection Softwares\91. captionhealth.com, Caption Health\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\AI Early Detection Softwares\92. therapixel.com, Therapixel — MammoScreen\original sources.txt ...
#   links found: 178 | deduplicated: 94 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\AI Early Detection Softwares\92. therapixel.com, Therapixel — MammoScreen\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\AI Early Detection Softwares\93. Infervision.com, InferRead Lung CT.AI\original sources.txt ...
#   links found: 150 | deduplicated: 73 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\AI Early Detection Softwares\93. Infervision.com, InferRead Lung CT.AI\deduplicated.json

# %% [markdown]
# # DICOM Routers

# %%
# Set the base directory that contains vendor subfolders.
base_dir = Path(r"C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\DICOM Routers")

source_files = list(base_dir.glob("*/original sources.txt"))
if not source_files:
    raise SystemExit("No 'original sources.txt' files found under the provided data directory.")

for src in source_files:
    print(f"Processing {src} ...")
    d1, d2 = process_file(src)
    save_output(src, d1, d2)
    print(f"  links found: {len(d1)} | deduplicated: {len(d2)} | output: {src.with_name('deduplicated.json')}")
# Out:
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\DICOM Routers\1. laurelbridge.com, Laurel Bridge Software - Compass, DICOM Router-Imaging Interoperability\original sources.txt ...
#   links found: 232 | deduplicated: 123 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\DICOM Routers\1. laurelbridge.com, Laurel Bridge Software - Compass, DICOM Router-Imaging Interoperability\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\DICOM Routers\10. intelerad.com, Intelerad InteleShare Gateway-IntelePACS, DICOM Router-Imaging Interoperability\original sources.txt ...
#   links found: 107 | deduplicated: 59 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\DICOM Routers\10. intelerad.com, Intelerad InteleShare Gateway-IntelePACS, DICOM Router-Imaging Interoperability\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\DICOM Routers\2. dcmsys.com, Dicom Systems - Unifier Platform, DICOM Router-Imaging Interoperability\original sources.txt ...
#   links found: 310 | deduplicated: 202 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\DICOM Routers\2. dcmsys.com, Dicom Systems - Unifier Platform, DICOM Router-Imaging Interoperability\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\DICOM Routers\3. hyland.com, Hyland Acuo VNA, DICOM Router-Imaging Interoperability\original sources.txt ...
#   links found: 182 | deduplicated: 123 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\DICOM Routers\3. hyland.com, Hyland Acuo VNA, DICOM Router-Imaging Interoperability\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\DICOM Routers\4. mach7t.com, Mach7 Enterprise Imaging Platform (EIP), DICOM Router-Imaging Interoperability\original sources.txt ...
#   links found: 123 | deduplicated: 66 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\DICOM Routers\4. mach7t.com, Mach7 Enterprise Imaging Platform (EIP), DICOM Router-Imaging Interoperability\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\DICOM Routers\5. agfahealthcare.com, AGFA HealthCare Enterprise Imaging, DICOM Router-Imaging Interoperability\original sources.txt ...
#   links found: 118 | deduplicated: 65 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\DICOM Routers\5. agfahealthcare.com, AGFA HealthCare Enterprise Imaging, DICOM Router-Imaging Interoperability\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\DICOM Routers\6. medical.sectra.com, Sectra Enterprise Imaging (Sectra PACS & Sectra VNA  Sectra Connectivity Hub), DICOM Router-Imaging Interoperability\original sources.txt ...
#   links found: 172 | deduplicated: 101 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\DICOM Routers\6. medical.sectra.com, Sectra Enterprise Imaging (Sectra PACS & Sectra VNA  Sectra Connectivity Hub), DICOM Router-Imaging Interoperability\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\DICOM Routers\7. philips.ae, Philips Enterprise Imaging, DICOM Router-Imaging Interoperability\original sources.txt ...
#   links found: 127 | deduplicated: 80 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\DICOM Routers\7. philips.ae, Philips Enterprise Imaging, DICOM Router-Imaging Interoperability\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\DICOM Routers\8. gehealthcare.com, GE HealthCare Enterprise Archive 8, DICOM Router-Imaging Interoperability\original sources.txt ...
#   links found: 120 | deduplicated: 84 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\DICOM Routers\8. gehealthcare.com, GE HealthCare Enterprise Archive 8, DICOM Router-Imaging Interoperability\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\DICOM Routers\9. healthcaresolutions-us.fujifilm.com, FUJIFILM SYNAPSE Enterprise Imaging (Synapse PACS-Synapse VNA), DICOM Router-Imaging Interoperability\original sources.txt ...
#   links found: 131 | deduplicated: 73 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\DICOM Routers\9. healthcaresolutions-us.fujifilm.com, FUJIFILM SYNAPSE Enterprise Imaging (Synapse PACS-Synapse VNA), DICOM Router-Imaging Interoperability\deduplicated.json

# %% [markdown]
# # PACS Dictation Softwares

# %%
# Set the base directory that contains vendor subfolders.
base_dir = Path(r"C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Dictation Softwares")

source_files = list(base_dir.glob("*/original sources.txt"))
if not source_files:
    raise SystemExit("No 'original sources.txt' files found under the provided data directory.")

for src in source_files:
    print(f"Processing {src} ...")
    d1, d2 = process_file(src)
    save_output(src, d1, d2)
    print(f"  links found: {len(d1)} | deduplicated: {len(d2)} | output: {src.with_name('deduplicated.json')}")
# Out:
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Dictation Softwares\1. nuance.com, Nuance PowerScribe 360 Reporting, E, F\original sources.txt ...
#   links found: 403 | deduplicated: 243 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Dictation Softwares\1. nuance.com, Nuance PowerScribe 360 Reporting, E, F\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Dictation Softwares\2. md.ai , MD.ai, AI-powered reporting and annotation for radiology, A,E,F\original sources.txt ...
#   links found: 276 | deduplicated: 107 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Dictation Softwares\2. md.ai , MD.ai, AI-powered reporting and annotation for radiology, A,E,F\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Dictation Softwares\3. nuance.com, Nuance Dragon Medical One, E\original sources.txt ...
#   links found: 392 | deduplicated: 179 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Dictation Softwares\3. nuance.com, Nuance Dragon Medical One, E\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Dictation Softwares\4. solventum.com, Solventum Fluency for Imaging, E,F\original sources.txt ...
#   links found: 297 | deduplicated: 141 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Dictation Softwares\4. solventum.com, Solventum Fluency for Imaging, E,F\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Dictation Softwares\5. dolbeyspeech.com, Fusion Narrate Dx & Fusion Expert, E,F\original sources.txt ...
#   links found: 308 | deduplicated: 146 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Dictation Softwares\5. dolbeyspeech.com, Fusion Narrate Dx & Fusion Expert, E,F\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Dictation Softwares\6. dolbeyspeech.com, Rad AI, F\original sources.txt ...
#   links found: 215 | deduplicated: 128 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Dictation Softwares\6. dolbeyspeech.com, Rad AI, F\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Dictation Softwares\7. magview.com, MagView, F,G\original sources.txt ...
#   links found: 219 | deduplicated: 112 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Dictation Softwares\7. magview.com, MagView, F,G\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Dictation Softwares\8. penrad.com, PenRad, B,D,G\original sources.txt ...
#   links found: 207 | deduplicated: 109 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Dictation Softwares\8. penrad.com, PenRad, B,D,G\deduplicated.json

# %% [markdown]
# # PACS Worklists Softwares

# %%
# Set the base directory that contains vendor subfolders.
base_dir = Path(r"C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Worklists Softwares")

source_files = list(base_dir.glob("*/original sources.txt"))
if not source_files:
    raise SystemExit("No 'original sources.txt' files found under the provided data directory.")

for src in source_files:
    print(f"Processing {src} ...")
    d1, d2 = process_file(src)
    save_output(src, d1, d2)
    print(f"  links found: {len(d1)} | deduplicated: {len(d2)} | output: {src.with_name('deduplicated.json')}")
# Out:
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Worklists Softwares\1. medical.sectra.com, Sectra IDS7 platform (radiology workflowPACS)\original sources.txt ...
#   links found: 234 | deduplicated: 133 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Worklists Softwares\1. medical.sectra.com, Sectra IDS7 platform (radiology workflowPACS)\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Worklists Softwares\10. novarad.net, Novarad NovaPACS  PACS worklistworkflow\original sources.txt ...
#   links found: 258 | deduplicated: 84 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Worklists Softwares\10. novarad.net, Novarad NovaPACS  PACS worklistworkflow\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Worklists Softwares\11. siemens-healthineers.com, Siemens Healthineers Syngo Carbon (enterprise imaging  reading workflow platform)\original sources.txt ...
#   links found: 250 | deduplicated: 134 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Worklists Softwares\11. siemens-healthineers.com, Siemens Healthineers Syngo Carbon (enterprise imaging  reading workflow platform)\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Worklists Softwares\12. hyland.com, Hyland, enterprise imaging viewerworkflow ecosystems\original sources.txt ...
#   links found: 239 | deduplicated: 151 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Worklists Softwares\12. hyland.com, Hyland, enterprise imaging viewerworkflow ecosystems\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Worklists Softwares\13. epic.com, Epic Radiant, RIS (Radiology Information System) - RIS-driven worklists\original sources.txt ...
#   links found: 147 | deduplicated: 80 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Worklists Softwares\13. epic.com, Epic Radiant, RIS (Radiology Information System) - RIS-driven worklists\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Worklists Softwares\14. oracle.com, [Oracle Health Radiology], RIS (Radiology Information System) - RIS-driven worklists\original sources.txt ...
#   links found: 366 | deduplicated: 239 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Worklists Softwares\14. oracle.com, [Oracle Health Radiology], RIS (Radiology Information System) - RIS-driven worklists\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Worklists Softwares\15. medinformatix.com, MedInformatix, RIS (Radiology Information System) - RIS-driven worklists\original sources.txt ...
#   links found: 174 | deduplicated: 105 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Worklists Softwares\15. medinformatix.com, MedInformatix, RIS (Radiology Information System) - RIS-driven worklists\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Worklists Softwares\16. business.optum.com, [Change Healthcare Stratus Imaging PACS], PACS - diagnostic viewer with radiologist reading worklist\original sources.txt ...
#   links found: 262 | deduplicated: 172 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Worklists Softwares\16. business.optum.com, [Change Healthcare Stratus Imaging PACS], PACS - diagnostic viewer with radiologist reading worklist\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Worklists Softwares\17. newvue.ai, [NewVue.ai Intelligent Worklist], Workflow-worklist orchestration overlay (PACS-agnostic)\original sources.txt ...
#   links found: 415 | deduplicated: 188 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Worklists Softwares\17. newvue.ai, [NewVue.ai Intelligent Worklist], Workflow-worklist orchestration overlay (PACS-agnostic)\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Worklists Softwares\18. nuance.com, [PowerScribe Workflow Orchestration], Workflow-worklist orchestration overlay (PACS-agnostic)\original sources.txt ...
#   links found: 200 | deduplicated: 135 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Worklists Softwares\18. nuance.com, [PowerScribe Workflow Orchestration], Workflow-worklist orchestration overlay (PACS-agnostic)\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Worklists Softwares\19. ramsoft.com, [RamSoft PowerServer], PACS - diagnostic viewer with radiologist reading worklist\original sources.txt ...
#   links found: 193 | deduplicated: 97 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Worklists Softwares\19. ramsoft.com, [RamSoft PowerServer], PACS - diagnostic viewer with radiologist reading worklist\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Worklists Softwares\2. intelerad.com, Intelerad (InteleViewer + InteleWorkflow)\original sources.txt ...
#   links found: 151 | deduplicated: 89 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Worklists Softwares\2. intelerad.com, Intelerad (InteleViewer + InteleWorkflow)\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Worklists Softwares\20. medical.sectra.com, Sectra Breast Imaging, PACS - diagnostic viewer with radiologist reading worklist\original sources.txt ...
#   links found: 344 | deduplicated: 202 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Worklists Softwares\20. medical.sectra.com, Sectra Breast Imaging, PACS - diagnostic viewer with radiologist reading worklist\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Worklists Softwares\21. hologic.com, Hologic SecurView Breast Imaging Workstations, PACS - diagnostic viewer with radiologist reading worklist\original sources.txt ...
#   links found: 324 | deduplicated: 163 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Worklists Softwares\21. hologic.com, Hologic SecurView Breast Imaging Workstations, PACS - diagnostic viewer with radiologist reading worklist\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Worklists Softwares\22. gehealthcare.com, Universal Viewer, PACS - diagnostic viewer with radiologist reading worklist\original sources.txt ...
#   links found: 264 | deduplicated: 179 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Worklists Softwares\22. gehealthcare.com, Universal Viewer, PACS - diagnostic viewer with radiologist reading worklist\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Worklists Softwares\23. healthcaresolutions-us.fujifilm.com, [Synapse Radiology PACS], PACS - diagnostic viewer with radiologist reading worklist\original sources.txt ...
#   links found: 182 | deduplicated: 107 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Worklists Softwares\23. healthcaresolutions-us.fujifilm.com, [Synapse Radiology PACS], PACS - diagnostic viewer with radiologist reading worklist\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Worklists Softwares\3. gehealthcare.com, GE HealthCare Centricity PACS\original sources.txt ...
#   links found: 343 | deduplicated: 237 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Worklists Softwares\3. gehealthcare.com, GE HealthCare Centricity PACS\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Worklists Softwares\4. healthcaresolutions-us.fujifilm.com, Fujifilm Synapse PACS + workflow components\original sources.txt ...
#   links found: 165 | deduplicated: 104 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Worklists Softwares\4. healthcaresolutions-us.fujifilm.com, Fujifilm Synapse PACS + workflow components\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Worklists Softwares\5. philips.com, Philips IntelliSpace (enterprise imaging workflow components), PACSworklistenterprise imaging\original sources.txt ...
#   links found: 334 | deduplicated: 204 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Worklists Softwares\5. philips.com, Philips IntelliSpace (enterprise imaging workflow components), PACSworklistenterprise imaging\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Worklists Softwares\6. agfahealthcare.com, Agfa HealthCare Enterprise Imaging + workflow\original sources.txt ...
#   links found: 283 | deduplicated: 134 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Worklists Softwares\6. agfahealthcare.com, Agfa HealthCare Enterprise Imaging + workflow\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Worklists Softwares\7. healthcare.konicaminolta.us, Konica Minolta Exa PACS + Exa Platform workflow components\original sources.txt ...
#   links found: 171 | deduplicated: 115 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Worklists Softwares\7. healthcare.konicaminolta.us, Konica Minolta Exa PACS + Exa Platform workflow components\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Worklists Softwares\8. visageimaging.com, Visage Imaging Visage 7 Enterprise Imaging Platform (enterprise imagingPACS + enterprise workflowworklist)\original sources.txt ...
#   links found: 193 | deduplicated: 102 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Worklists Softwares\8. visageimaging.com, Visage Imaging Visage 7 Enterprise Imaging Platform (enterprise imagingPACS + enterprise workflowworklist)\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Worklists Softwares\9. carestream.com, Carestream Vue PACS, radiology PACSworkflow\original sources.txt ...
#   links found: 274 | deduplicated: 153 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\PACS Worklists Softwares\9. carestream.com, Carestream Vue PACS, radiology PACSworkflow\deduplicated.json

# %% [markdown]
# # Radiologist Reading Workstations (Computers, Monitors)

# %%
# Set the base directory that contains vendor subfolders.
base_dir = Path(r"C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\Radiologist Reading Workstations (Computers, Monitors)")

source_files = list(base_dir.glob("*/original sources.txt"))
if not source_files:
    raise SystemExit("No 'original sources.txt' files found under the provided data directory.")

for src in source_files:
    print(f"Processing {src} ...")
    d1, d2 = process_file(src)
    save_output(src, d1, d2)
    print(f"  links found: {len(d1)} | deduplicated: {len(d2)} | output: {src.with_name('deduplicated.json')}")
# Out:
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\Radiologist Reading Workstations (Computers, Monitors)\1. barco.com, [QAWeb Enterprise], PACS Radiology Reading Workstation Hardware\original sources.txt ...
#   links found: 458 | deduplicated: 216 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\Radiologist Reading Workstations (Computers, Monitors)\1. barco.com, [QAWeb Enterprise], PACS Radiology Reading Workstation Hardware\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\Radiologist Reading Workstations (Computers, Monitors)\2. eizo.com, [RadiForce RX---], PACS Radiology Reading Workstation Hardware\original sources.txt ...
#   links found: 193 | deduplicated: 77 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\Radiologist Reading Workstations (Computers, Monitors)\2. eizo.com, [RadiForce RX---], PACS Radiology Reading Workstation Hardware\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\Radiologist Reading Workstations (Computers, Monitors)\3. ndssi.com, NDS Surgical Imaging (NDSsi) medical displays, PACS Radiology Reading Workstation Hardware\original sources.txt ...
#   links found: 283 | deduplicated: 145 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\Radiologist Reading Workstations (Computers, Monitors)\3. ndssi.com, NDS Surgical Imaging (NDSsi) medical displays, PACS Radiology Reading Workstation Hardware\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\Radiologist Reading Workstations (Computers, Monitors)\4. dell.com, Dell Precision, PACS Radiology Reading Workstation Hardware\original sources.txt ...
#   links found: 131 | deduplicated: 66 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\Radiologist Reading Workstations (Computers, Monitors)\4. dell.com, Dell Precision, PACS Radiology Reading Workstation Hardware\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\Radiologist Reading Workstations (Computers, Monitors)\5. hp.com, HP Z Workstations, PACS Radiology Reading Workstation Hardware\original sources.txt ...
#   links found: 216 | deduplicated: 128 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\Radiologist Reading Workstations (Computers, Monitors)\5. hp.com, HP Z Workstations, PACS Radiology Reading Workstation Hardware\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\Radiologist Reading Workstations (Computers, Monitors)\6. lenovo.com, Lenovo ThinkStation, PACS Radiology Reading Workstation Hardware\original sources.txt ...
#   links found: 118 | deduplicated: 68 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\Radiologist Reading Workstations (Computers, Monitors)\6. lenovo.com, Lenovo ThinkStation, PACS Radiology Reading Workstation Hardware\deduplicated.json
# Processing C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\Radiologist Reading Workstations (Computers, Monitors)\7. boxx.com, BOXX (High-Performance Imaging Workstations), PACS Radiology Reading Workstation Hardware\original sources.txt ...
#   links found: 143 | deduplicated: 87 | output: C:\Users\Ans\Desktop\code\36_PACS_PROS\agents\data\Radiologist Reading Workstations (Computers, Monitors)\7. boxx.com, BOXX (High-Performance Imaging Workstations), PACS Radiology Reading Workstation Hardware\deduplicated.json
