# %%
from langgraph.graph import END, MessagesState, StateGraph
from langchain_core.runnables import RunnableConfig
from langchain_core.messages import HumanMessage, SystemMessage, AIMessage

from core import get_model, settings


class AgentState(MessagesState, total=False):
    """`total=False` marks fields added here as optional (PEP 589),
    while inherited fields (like `messages` from MessagesState) keep their original requirements.

    documentation: https://typing.readthedocs.io/en/latest/spec/typeddict.html#totality
    """
    # # Safety metadata from LlamaGuard (populated by guard nodes)
    # safety: LlamaGuardOutput

    # # LangGraph-managed remaining step budget for the current run
    # remaining_steps: RemainingSteps


MODEL_SYSTEM_MESSAGE = """ You are a helpful chatbot on the website of an accounting firm.
Your role is to provide users with accurate information about the firm’s services.
The details of services provided by the accounting firm are as follows:

<accounting_services>
{accounting_services}
</accounting_services>
"""


accounting_services = 'null'


async def acall_model(state: AgentState, config: RunnableConfig) -> AgentState:
    """Main model node:
       - Selects the concrete model (from config or default),
       - Runs the tool-enabled chat model,
       - Post-checks the output with LlamaGuard,
       - Enforces step budget if tool calls remain."""
    
    # can later decide to pace it outside the fn, if observed high latency in traces
    model      = get_model(config["configurable"].get("model", settings.DEFAULT_MODEL))

    
    system_msg = MODEL_SYSTEM_MESSAGE.format(accounting_services=accounting_services)
    response   = await model.ainvoke(
                                        [SystemMessage(content=system_msg)] + state["messages"],
                                        config=config
                                    )
    
    return {"messages": [response]}



# -------------------------
# BUILD THE GRAPH
# -------------------------


# from IPython.display import Image, display
from langgraph.graph import StateGraph, START, END
from langchain_core.messages import HumanMessage, SystemMessage


builder = StateGraph(AgentState)

builder.add_node("acall_model", acall_model)

builder.set_entry_point("acall_model")
builder.add_edge('acall_model', END)


# Compile the graph with persistent checkpointer and in-memory store
basic_langgraph_agent = builder.compile()#checkpointer=memory, store=across_thread_memory) #checkpointer
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from langgraph.graph import END, MessagesState, StateGraph
#       2 from langchain_core.runnables import RunnableConfig
#       3 from langchain_core.messages import HumanMessage, SystemMessage, AIMessage
#
# File ~\Desktop\code\36_Data_Collection_Agent\.venv\Lib\site-packages\langgraph\graph\__init__.py:2
#       1 from langgraph.constants import END, START
# ----> 2 from langgraph.graph.message import MessageGraph, MessagesState, add_messages
#       3 from langgraph.graph.state import StateGraph
#       5 __all__ = [
#       6     "END",
#       7     "START",
#    (...)     11     "MessagesState",
#      12 ]
#
# File ~\Desktop\code\36_Data_Collection_Agent\.venv\Lib\site-packages\langgraph\graph\message.py:28
#      25 from typing_extensions import TypedDict
#      27 from langgraph.constants import CONF, CONFIG_KEY_SEND
# ---> 28 from langgraph.graph.state import StateGraph
#      30 Messages = Union[list[MessageLikeRepresentation], MessageLikeRepresentation]
#      32 REMOVE_ALL_MESSAGES = "__remove_all__"
#
# File ~\Desktop\code\36_Data_Collection_Agent\.venv\Lib\site-packages\langgraph\graph\state.py:59
#      42 from langgraph.constants import (
#      43     EMPTY_SEQ,
#      44     END,
#    (...)     51     TASKS,
#      52 )
#      53 from langgraph.errors import (
#      54     ErrorCode,
#      55     InvalidUpdateError,
#      56     ParentCommand,
#      57     create_error_message,
#      58 )
# ---> 59 from langgraph.graph.branch import Branch
#      60 from langgraph.managed.base import (
#      61     ManagedValueSpec,
#      62     is_managed_value,
#      63 )
#      64 from langgraph.pregel import Pregel
#
# File ~\Desktop\code\36_Data_Collection_Agent\.venv\Lib\site-packages\langgraph\graph\branch.py:31
#      29 from langgraph.constants import END, START
#      30 from langgraph.errors import InvalidUpdateError
# ---> 31 from langgraph.pregel.write import PASSTHROUGH, ChannelWrite, ChannelWriteEntry
#      32 from langgraph.types import Send
#      33 from langgraph.utils.runnable import (
#      34     RunnableCallable,
#      35 )
#
# File ~\Desktop\code\36_Data_Collection_Agent\.venv\Lib\site-packages\langgraph\pregel\__init__.py:71
#      64 from langgraph.errors import (
#      65     ErrorCode,
#      66     GraphRecursionError,
#      67     InvalidUpdateError,
#      68     create_error_message,
#      69 )
#      70 from langgraph.managed.base import ManagedValueSpec
# ---> 71 from langgraph.pregel.algo import (
#      72     PregelTaskWrites,
#      73     _scratchpad,
#      74     apply_writes,
#      75     local_read,
#      76     prepare_next_tasks,
#      77 )
#      78 from langgraph.pregel.call import identifier
#      79 from langgraph.pregel.checkpoint import (
#      80     channels_from_checkpoint,
#      81     copy_checkpoint,
#      82     create_checkpoint,
#      83     empty_checkpoint,
#      84 )
#
# File ~\Desktop\code\36_Data_Collection_Agent\.venv\Lib\site-packages\langgraph\pregel\algo.py:73
#      71 from langgraph.pregel.io import read_channels
#      72 from langgraph.pregel.log import logger
# ---> 73 from langgraph.pregel.read import INPUT_CACHE_KEY_TYPE, PregelNode
#      74 from langgraph.store.base import BaseStore
#      75 from langgraph.types import (
#      76     All,
#      77     CacheKey,
#    (...)     82     RetryPolicy,
#      83 )
#
# File ~\Desktop\code\36_Data_Collection_Agent\.venv\Lib\site-packages\langgraph\pregel\read.py:14
#      11 from langchain_core.runnables import Runnable, RunnableConfig
#      13 from langgraph.constants import CONF, CONFIG_KEY_READ
# ---> 14 from langgraph.pregel.protocol import PregelProtocol
#      15 from langgraph.pregel.utils import find_subgraph_pregel
#      16 from langgraph.pregel.write import ChannelWrite
#
# File ~\Desktop\code\36_Data_Collection_Agent\.venv\Lib\site-packages\langgraph\pregel\protocol.py:16
#      12 from langgraph.typing import InputT, OutputT, StateT
#      15 # TODO: remove Runnable inheritance here!
# ---> 16 class PregelProtocol(Runnable[InputT, Any], Generic[StateT, InputT, OutputT], ABC):
#      17     @abstractmethod
#      18     def with_config(
#      19         self, config: RunnableConfig | None = None, **kwargs: Any
#      20     ) -> Self: ...
#
# File <frozen abc>:106, in __new__(mcls, name, bases, namespace, **kwargs)
#
# TypeError: Cannot create a consistent method resolution order (MRO) for bases ABC, Generic
